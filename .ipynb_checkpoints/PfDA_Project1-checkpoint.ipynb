# %% [markdown]
# ### Programming for Data Analysis Project 1

# %% [markdown]
# ### 1. Introduction
#
# For this project we chose **Quality of Life** dataset by O.Karaman retreived from Kaggle platform.[[1]](https://www.kaggle.com/datasets/orhankaramancode/city-quality-of-life-dataset) Data were acquired from Teleport.org and contain scores on different variables about the life in the cities around the world allowing users to compare them in order to ease the decision of choosing a place to live. [[2]](https://teleport.org/about-us/)
#
# To simplify the analysis, we didn't use the entire data set, instead we picked some of the variables we found the most interesting and explored the relationship between them. Initially, eight variables were chosen: Name of the City, Country, Continent and scores variables: Business Freedom, Safety, Education, Economy and Tolerance. The idea was to see how the Tolerance scores vary depending on the other scores variables but the correlation between them turned out to be low which made data generating more difficult. The choice of the variables was changed after we checked the correlation for the whole data set. New variables that were analysed are: **City, Country, Continent, Housing, Cost of Living, Business Freedom and Education**.
#
# To describe what **variables** are representing we took a look behind data at Teleport.org:[[3]](https://teleport.org/cities/dublin/)
#
# **Housing** includes prices of the apartments and rent index,
# **Cost of Living** refers to groceries and transport expenses as well as the inflation score,
# **Business Freedom** implies freedom from corruption and labor restrictions,
# **Education** refers to PISA ranking, happiness of the students and university quality

# %% [markdown]
# ### 2. Exploring Data

# %% [markdown]
# Even though data were already pre-processed, since we didn't use the whole data set, additional cleaning was done.
# First, we took a look at data as they were retrieved. They are uploaded in csv format as scoresData.csv.

# %% [markdown]
# #### 2.1. Importing libraries and reading data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns
import sys

# %%
scores = pd.read_csv('scoresData.csv')

# %% [markdown]
# To see the first couple of rows we used the head() function.
# We have 21 columns of which the first one shows indexes of rows, next three are Name (of the cities), Country and Continent for which the scores in the variables are shown.

# %%
scores.head()
# Out:
#    Unnamed: 0      UA_Name    UA_Country   UA_Continent  Housing  \
# 0           0       Aarhus       Denmark         Europe   6.1315
# 1           1     Adelaide     Australia        Oceania   6.3095
# 2           2  Albuquerque    New Mexico  North America   7.2620
# 3           3       Almaty    Kazakhstan           Asia   9.2820
# 4           4    Amsterdam   Netherlands         Europe   3.0530
#
#    Cost of Living  Startups  Venture Capital  Travel Connectivity  Commute  \
# 0           4.015    2.8270            2.512               3.5360  6.31175
# 1           4.692    3.1365            2.640               1.7765  5.33625
# 2           6.059    3.7720            1.493               1.4555  5.05575
# 3           9.333    2.4585            0.000               4.5920  5.87125
# 4           3.824    7.9715            6.107               8.3245  6.11850
#
#    ...  Safety  Healthcare  Education  Environmental Quality  Economy  \
# ...

# %% [markdown]
# #### 2.2. Types of data

# %% [markdown]
# Types of data in dataframe are checked with the info() function. Scores for variables such as Housing, Cost of Living, Startups and the rest are float data type while categorial variables: Name (of the city), Country and Continent have object data types.
# According to the output none of the entries are null, there are no missing values, although, just by looking at data we can see zeroes are included. Since we didn't use the entire dataset, we dealt with zeroes later, after we picked the variables for analysis.

# %%
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             266 non-null    int64
#  1   UA_Name                266 non-null    object
#  2   UA_Country             266 non-null    object
#  3   UA_Continent           266 non-null    object
#  4   Housing                266 non-null    float64
#  5   Cost of Living         266 non-null    float64
#  6   Startups               266 non-null    float64
#  7   Venture Capital        266 non-null    float64
#  8   Travel Connectivity    266 non-null    float64
#  9   Commute                266 non-null    float64
#  10  Business Freedom       266 non-null    float64
#  11  Safety                 266 non-null    float64
#  12  Healthcare             266 non-null    float64
#  13  Education              266 non-null    float64
# ...

# %% [markdown]
# ### 3. Data Cleaning

# %% [markdown]
# #### 3.1. Rename columns

# %% [markdown]
# To make data set look neat we changed the names of the variables.

# %%
scores = scores.rename(columns={"UA_Name": "City", "UA_Country": "Country", "UA_Continent": "Continent"})
scores
# Out:
#      Unnamed: 0         City       Country      Continent  Housing  \
# 0             0       Aarhus       Denmark         Europe   6.1315
# 1             1     Adelaide     Australia        Oceania   6.3095
# 2             2  Albuquerque    New Mexico  North America   7.2620
# 3             3       Almaty    Kazakhstan           Asia   9.2820
# 4             4    Amsterdam   Netherlands         Europe   3.0530
# ..          ...          ...           ...            ...      ...
# 261         261     Winnipeg        Canada  North America   7.5525
# 262         262      Wroclaw        Poland         Europe   8.4520
# 263         263      Yerevan       Armenia           Asia   9.6945
# 264         264       Zagreb       Croatia         Europe   8.9100
# 265         265       Zurich   Switzerland         Europe   1.4730
#
#      Cost of Living  Startups  Venture Capital  Travel Connectivity  Commute  \
# 0             4.015    2.8270            2.512               3.5360  6.31175
# ...

# %% [markdown]
# After exploring the ways of how to remove columns we don't want in a data set, it was decided we are going to drop them by indexes. This was the initial choice of the variables: City, Country, Continent, Business Freedom, Safety, Education, Economy and Tolerance.

# %% [markdown]
# #### 3.2. Drop columns

# %%
# axis=1 because we are taking out columns, for rows would be axis=0
scores1 = scores.drop(scores.columns[[0, 4, 5, 6, 7, 8, 9, 12, 16, 14, 17, 18, 20]], axis=1)
scores1
# Out:
#             City       Country      Continent  Business Freedom  Safety  \
# 0         Aarhus       Denmark         Europe          9.940000  9.6165
# 1       Adelaide     Australia        Oceania          9.399667  7.9260
# 2    Albuquerque    New Mexico  North America          8.671000  1.3435
# 3         Almaty    Kazakhstan           Asia          5.568000  7.3090
# 4      Amsterdam   Netherlands         Europe          8.836667  8.5035
# ..           ...           ...            ...               ...     ...
# 261     Winnipeg        Canada  North America          8.966000  6.0155
# 262      Wroclaw        Poland         Europe          5.704333  8.1655
# 263      Yerevan       Armenia           Asia          6.501000  8.8730
# 264       Zagreb       Croatia         Europe          5.720333  8.6575
# 265       Zurich   Switzerland         Europe          8.888000  9.0665
#
#      Education  Economy  Tolerance
# 0       5.3665   4.8865     9.7385
# ...

# %% [markdown]
# #### 3.2. Correlation

# %% [markdown]
# The highest correlation in the data set scores1 was between Business Freedom and Education (**0.75**) and Business Freedom and Economy (**0.63**). Tolerance and Safety were not correlated well to any of the variables.

# %%
scores1.corr()
# Out:
#                   Business Freedom    Safety  Education   Economy  Tolerance
# Business Freedom          1.000000 -0.039642   0.757955  0.633438   0.362165
# Safety                   -0.039642  1.000000   0.063285 -0.241724   0.374310
# Education                 0.757955  0.063285   1.000000  0.513191   0.290475
# Economy                   0.633438 -0.241724   0.513191  1.000000   0.049305
# Tolerance                 0.362165  0.374310   0.290475  0.049305   1.000000

# %% [markdown]
# The correlation between all the variables was checked. To style the matrix we used this code [[4]](https://towardsdatascience.com/prettifying-pandas-dataframes-75c1a1a6877d)

# %%
type(scores.style)
# Out:
# pandas.io.formats.style.Styler

# %%
correlation_matrix = scores.corr()
(correlation_matrix.style
     .background_gradient(cmap='viridis', axis=None)
     .set_properties(**{'text-align': 'center', 'padding': '12px'})
     .set_caption('CORRELATION MATRIX'))
# Out:
# <style type="text/css">
# #T_5f00a_row0_col0, #T_5f00a_row1_col1, #T_5f00a_row2_col2, #T_5f00a_row3_col3, #T_5f00a_row4_col4, #T_5f00a_row5_col5, #T_5f00a_row6_col6, #T_5f00a_row7_col7, #T_5f00a_row8_col8, #T_5f00a_row9_col9, #T_5f00a_row10_col10, #T_5f00a_row11_col11, #T_5f00a_row12_col12, #T_5f00a_row13_col13, #T_5f00a_row14_col14, #T_5f00a_row15_col15, #T_5f00a_row16_col16, #T_5f00a_row17_col17 {
#   background-color: #fde725;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
# }
# #T_5f00a_row0_col1, #T_5f00a_row1_col0, #T_5f00a_row1_col13, #T_5f00a_row1_col15, #T_5f00a_row13_col1, #T_5f00a_row15_col1 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_5f00a_row0_col2, #T_5f00a_row2_col0, #T_5f00a_row3_col13, #T_5f00a_row13_col3 {
#   background-color: #30698e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_5f00a_row0_col3, #T_5f00a_row3_col0 {
#   background-color: #2a768e;
# ...

# %% [markdown]
# Based on correlation table we decided to keep **City, Country, Continent, Housing, Cost of Living, Business Freedom and Education.**

# %% [markdown]
# #### 3.3. Drop more columns

# %%
scores = scores.drop(scores.columns[[0, 6, 7, 8, 9, 11, 12, 14, 15, 16, 17, 18, 19, 20]], axis=1)
scores
# Out:
#             City       Country      Continent  Housing  Cost of Living  \
# 0         Aarhus       Denmark         Europe   6.1315           4.015
# 1       Adelaide     Australia        Oceania   6.3095           4.692
# 2    Albuquerque    New Mexico  North America   7.2620           6.059
# 3         Almaty    Kazakhstan           Asia   9.2820           9.333
# 4      Amsterdam   Netherlands         Europe   3.0530           3.824
# ..           ...           ...            ...      ...             ...
# 261     Winnipeg        Canada  North America   7.5525           5.882
# 262      Wroclaw        Poland         Europe   8.4520           8.434
# 263      Yerevan       Armenia           Asia   9.6945           9.431
# 264       Zagreb       Croatia         Europe   8.9100           7.194
# 265       Zurich   Switzerland         Europe   1.4730           1.000
#
#      Business Freedom  Education
# 0            9.940000     5.3665
# 1            9.399667     5.1420
# ...

# %% [markdown]
# #### 3.4. Zero values

# %% [markdown]
# Next, we checked for zeroes in columns containing scores. Index slicing was used to remove zero values. [[3]](https://www.youtube.com/watch?v=i4cI4y9cLzg)

# %%
scores.columns[3:]
# Out:
# Index(['Housing', 'Cost of Living', 'Business Freedom', 'Education'], dtype='object')

# %%
scores[(scores[scores.columns[3:]]==0).any(axis=1)]
# Out:
#                 City                  Country      Continent  Housing  \
# 6            Andorra                  Andorra         Europe   3.9690
# 9           Asuncion                 Paraguay  South America   9.2265
# 14              Baku               Azerbaijan           Asia   9.7450
# 15              Bali                Indonesia           Asia   5.0000
# 23       Belize City                   Belize  North America   4.6425
# 37           Bozeman                  Montana  North America   2.9490
# 52           Caracas                Venezuela  South America   4.9025
# 54        Casablanca                  Morocco         Africa   8.8220
# 73     Dar es Salaam                 Tanzania         Africa   7.6520
# 89      Fort Collins                 Colorado  North America   2.7445
# 91           Fukuoka                    Japan           Asia   4.0100
# 95         Gibraltar                Gibraltar         Europe   1.1120
# ...

# %% [markdown]
# After removing zeroes we got dataset of 229 rows through 7 columns

# %%
scores = scores[~(scores[scores.columns[3:]]==0).any(axis=1)]
scores
# Out:
#             City       Country      Continent  Housing  Cost of Living  \
# 0         Aarhus       Denmark         Europe   6.1315           4.015
# 1       Adelaide     Australia        Oceania   6.3095           4.692
# 2    Albuquerque    New Mexico  North America   7.2620           6.059
# 3         Almaty    Kazakhstan           Asia   9.2820           9.333
# 4      Amsterdam   Netherlands         Europe   3.0530           3.824
# ..           ...           ...            ...      ...             ...
# 260   Wellington   New Zealand        Oceania   5.1345           5.161
# 261     Winnipeg        Canada  North America   7.5525           5.882
# 262      Wroclaw        Poland         Europe   8.4520           8.434
# 264       Zagreb       Croatia         Europe   8.9100           7.194
# 265       Zurich   Switzerland         Europe   1.4730           1.000
#
#      Business Freedom  Education
# 0            9.940000     5.3665
# 1            9.399667     5.1420
# ...

# %% [markdown]
# #### 3.5. Round

# %% [markdown]
# To get all scores with the same number of decimals we used round function.

# %%
scores.round(decimals=3)
# Out:
#             City       Country      Continent  Housing  Cost of Living  \
# 0         Aarhus       Denmark         Europe    6.132           4.015
# 1       Adelaide     Australia        Oceania    6.310           4.692
# 2    Albuquerque    New Mexico  North America    7.262           6.059
# 3         Almaty    Kazakhstan           Asia    9.282           9.333
# 4      Amsterdam   Netherlands         Europe    3.053           3.824
# ..           ...           ...            ...      ...             ...
# 260   Wellington   New Zealand        Oceania    5.134           5.161
# 261     Winnipeg        Canada  North America    7.552           5.882
# 262      Wroclaw        Poland         Europe    8.452           8.434
# 264       Zagreb       Croatia         Europe    8.910           7.194
# 265       Zurich   Switzerland         Europe    1.473           1.000
#
#      Business Freedom  Education
# 0               9.940      5.366
# 1               9.400      5.142
# ...

# %% [markdown]
# ### 4. Statistics

# %% [markdown]
# #### 4.1. Descriptive statistics

# %%
scores.describe()
# Out:
#           Housing  Cost of Living  Business Freedom   Education
# count  229.000000      229.000000        229.000000  229.000000
# mean     6.531417        5.963904          7.710937    4.258179
# std      2.135435        1.878591          1.736523    1.929332
# min      1.000000        1.000000          2.781000    0.500000
# 25%      5.433500        4.927000          6.212667    3.624500
# 50%      6.727000        5.623000          8.671000    4.393500
# 75%      8.177000        7.237000          8.888000    5.345500
# max     10.000000       10.000000         10.000000    9.711000

# %% [markdown]
# #### 4.2. Group by continents

# %% [markdown]
# First, we grouped cities by continents, then we did strip plots of the variables.

# %%
scores['Continent'].value_counts()
# Out:
# Europe           105
# North America     73
# Asia              27
# South America     11
# Oceania            8
# Africa             5
# Name: Continent, dtype: int64

# %% [markdown]
# #### 4.3. Strip plots

# %% [markdown]
# Strip plot for each score variable grouped by continents. [[5]](https://seaborn.pydata.org/generated/seaborn.stripplot.html)

# %%
plt.figure(figsize = (22,22))

plt.subplot(5, 5, 1)
sns.stripplot(data=scores, x='Continent', y='Housing', jitter=False, s=20, marker="D", linewidth=1, alpha=.9, palette="viridis")
plt.xticks(rotation=60);

plt.subplot(5, 5, 2)
sns.stripplot(data=scores, x='Continent', y='Cost of Living', jitter=False, s=20, marker="D", linewidth=1, alpha=.9, palette="viridis")
plt.xticks(rotation=60);

# %%
plt.figure(figsize = (22,22))

plt.subplot(5, 5, 1)
sns.stripplot(data=scores, x='Continent', y='Business Freedom', jitter=False, s=20, marker="D", linewidth=1, alpha=.9, palette="viridis")
plt.xticks(rotation=60);

plt.subplot(5, 5, 2)
sns.stripplot(data=scores, x='Continent', y='Education', jitter=False, s=20, marker="D", linewidth=1, alpha=.9, palette="viridis")
plt.xticks(rotation=60);

# %%
print(sns.color_palette("viridis").as_hex())
# Out:
# ['#46327e', '#365c8d', '#277f8e', '#1fa187', '#4ac16d', '#a0da39']

# %% [markdown]
# #### 4.4. Histograms

# %%
plt.figure(figsize = (9,9))

plt.subplot(2, 2, 1)
plt.hist(scores['Housing'], color='#46327e')
plt.title(label='Housing');

plt.subplot(2, 2, 2)
plt.hist(scores['Cost of Living'], color='#a0da39')
plt.title(label='Cost of Living');

plt.subplot(2, 2, 3)
plt.hist(scores['Business Freedom'], color='#365c8d')
plt.title(label='Business Freedom');

plt.subplot(2, 2, 4)
plt.hist(scores['Education'], color='#4ac16d')
plt.title(label='Education');

# %% [markdown]
# #### 4.5. Correlation

# %% [markdown]
# After checking the correlation between variables we created scatterplots and a pairplot. Positive correlation is found between Housing and Cost of Living (**0.78**) and Business Freedom and Education (**0.67**).
# Other correlations were negative, the highest between Cost of Living and Business Freedom (**-0.72**), Cost of Living and Education (**-0.69**) and Housing and Education (**-0.67**).

# %%
scores.corr()
# Out:
#                    Housing  Cost of Living  Business Freedom  Education
# Housing           1.000000        0.783637         -0.564009  -0.677656
# Cost of Living    0.783637        1.000000         -0.724444  -0.691075
# Business Freedom -0.564009       -0.724444          1.000000   0.677346
# Education        -0.677656       -0.691075          0.677346   1.000000

# %%
fig, (ax1, ax2, ax3)=plt.subplots(1,3, figsize=(15,4))
scores.plot.scatter(x='Housing', y='Cost of Living', s=40, c='#46327e', ax=ax1);
scores.plot.scatter(x='Housing', y='Business Freedom', s=40, c='#a0da39', ax=ax2);
scores.plot.scatter(x='Housing', y='Education', s=40, c='#365c8d', ax=ax3);

fig, (ax1, ax2, ax3)=plt.subplots(1,3, figsize=(15,4))
scores.plot.scatter(x='Cost of Living', y='Business Freedom', s=40, c='#4ac16d', ax=ax1);
scores.plot.scatter(x='Cost of Living', y='Education', s=40, c='#46327e', ax=ax2);
scores.plot.scatter(x='Business Freedom', y='Education', s=40, c='#46327e', ax=ax3);

# %%
g = sns.PairGrid(scores)
g.map_upper(sns.scatterplot,color='#46327e')
g.map_lower(sns.scatterplot, color='#a0da39')
g.map_diag(sns.histplot);

# %% [markdown]
# ### 5. Random number generator

# %% [markdown]
# #### 5.1. Slicing and reading dataset

# %%
# These are data we took out and kept in a different data set
scorescontrol = scores.iloc[200:]
scorescontrol.to_csv('scorescontrol.csv')

# %%
# Then we read them
scores2 = pd.read_csv('scorescontrol.csv')
scores2
# Out:
#     Unnamed: 0            City                Country      Continent  Housing  \
# 0          234         Tallinn                Estonia         Europe   8.3765
# 1          235  Tampa Bay Area                Florida  North America   5.6960
# 2          236         Tampere                Finland         Europe   6.9360
# 3          237           Tartu                Estonia         Europe   8.9610
# 4          239         Tbilisi                Georgia         Europe   9.4905
# 5          240          Tehran                   Iran           Asia   8.3030
# 6          241        Tel Aviv                 Israel           Asia   4.9100
# 7          242       The Hague            Netherlands         Europe   6.0530
# 8          243    Thessaloniki                 Greece         Europe   9.3775
# 9          244           Tokyo                  Japan           Asia   5.6570
# 10         245         Toronto                 Canada  North America   4.6600
# ...

# %%
# Then we dropped the columns
scores2 = scores2.drop(scores2.columns[[0, 5, 7]], axis=1)
scores2
# Out:
#               City                Country      Continent  Housing  \
# 0          Tallinn                Estonia         Europe   8.3765
# 1   Tampa Bay Area                Florida  North America   5.6960
# 2          Tampere                Finland         Europe   6.9360
# 3            Tartu                Estonia         Europe   8.9610
# 4          Tbilisi                Georgia         Europe   9.4905
# 5           Tehran                   Iran           Asia   8.3030
# 6         Tel Aviv                 Israel           Asia   4.9100
# 7        The Hague            Netherlands         Europe   6.0530
# 8     Thessaloniki                 Greece         Europe   9.3775
# 9            Tokyo                  Japan           Asia   5.6570
# 10         Toronto                 Canada  North America   4.6600
# 11        Toulouse                 France         Europe   7.5440
# 12           Tunis                Tunisia         Africa   9.9680
# ...

# %% [markdown]
# Quartile values were taken from summary statistics for _scores_.

# %%
scores.describe()
# Out:
#           Housing  Cost of Living  Business Freedom   Education
# count  229.000000      229.000000        229.000000  229.000000
# mean     6.531417        5.963904          7.710937    4.258179
# std      2.135435        1.878591          1.736523    1.929332
# min      1.000000        1.000000          2.781000    0.500000
# 25%      5.433500        4.927000          6.212667    3.624500
# 50%      6.727000        5.623000          8.671000    4.393500
# 75%      8.177000        7.237000          8.888000    5.345500
# max     10.000000       10.000000         10.000000    9.711000

# %% [markdown]
# #### 5.2. Generating random number

# %% [markdown]
# We generated random numbers according to quartiles of the variables. First, we generated Cost of Living scores based on quartiles from Housing.
# These two variables were chosen because of the positive correlation (**0.78**).

# %%
rng = np.random.default_rng()
def cost(house):
    if house <= 5.433500:
        return rng.random() * (4.927000-1.000000) + 1.000000
    if house <= 6.727000:
        return rng.random() * (5.623000-4.927000) + 4.927000
    if house <= 8.177000:
        return rng.random() * (7.237000-5.623000) + 5.623000
    else: 
        return rng.random() * (10.000000-7.237000) + 7.237000

# %% [markdown]
# #### 5.4. Adding new column

# %% [markdown]
# We added a new column to the control dataset with generated numbers.

# %%
scores2.insert(4, 'Cost of Living', True)
scores2['Cost of Living'] = scores2['Housing'].apply(cost)
scores2
# Out:
#               City                Country      Continent  Housing  \
# 0          Tallinn                Estonia         Europe   8.3765
# 1   Tampa Bay Area                Florida  North America   5.6960
# 2          Tampere                Finland         Europe   6.9360
# 3            Tartu                Estonia         Europe   8.9610
# 4          Tbilisi                Georgia         Europe   9.4905
# 5           Tehran                   Iran           Asia   8.3030
# 6         Tel Aviv                 Israel           Asia   4.9100
# 7        The Hague            Netherlands         Europe   6.0530
# 8     Thessaloniki                 Greece         Europe   9.3775
# 9            Tokyo                  Japan           Asia   5.6570
# 10         Toronto                 Canada  North America   4.6600
# 11        Toulouse                 France         Europe   7.5440
# 12           Tunis                Tunisia         Africa   9.9680
# ...

# %% [markdown]
# Then we generated data for one more variable, Education based on quartiles from Business Freedom. Their correlation was **0.67**

# %%
rng = np.random.default_rng()
def efg(bf):
    if bf <= 6.212667:
        return rng.random() * (3.624500-0.500000) + 0.500000
    if bf <= 8.671000:
        return rng.random() * (4.393500-3.624500) + 3.624500
    if bf <= 8.888000:
        return rng.random() * (5.345500-4.393500) + 4.393500
    else: 
        return rng.random() * (9.711000-5.345500) + 5.345500

# %% [markdown]
# Then we added it to dataset.

# %%
scores2.insert(6, 'Education', True)
scores2['Education'] = scores2['Business Freedom'].apply(efg)
scores2
# Out:
#               City                Country      Continent  Housing  \
# 0          Tallinn                Estonia         Europe   8.3765
# 1   Tampa Bay Area                Florida  North America   5.6960
# 2          Tampere                Finland         Europe   6.9360
# 3            Tartu                Estonia         Europe   8.9610
# 4          Tbilisi                Georgia         Europe   9.4905
# 5           Tehran                   Iran           Asia   8.3030
# 6         Tel Aviv                 Israel           Asia   4.9100
# 7        The Hague            Netherlands         Europe   6.0530
# 8     Thessaloniki                 Greece         Europe   9.3775
# 9            Tokyo                  Japan           Asia   5.6570
# 10         Toronto                 Canada  North America   4.6600
# 11        Toulouse                 France         Europe   7.5440
# 12           Tunis                Tunisia         Africa   9.9680
# ...

# %% [markdown]
# #### 5.5. Statistics summary for scores2

# %%
scores2.describe()
# Out:
#          Housing  Cost of Living  Business Freedom  Education
# count  29.000000       29.000000         29.000000  29.000000
# mean    6.814190        6.069180          7.875299   4.417745
# std     2.191111        2.262388          1.432390   1.762808
# min     1.210500        1.292133          4.342667   1.255702
# 25%     5.657000        4.985627          6.790000   3.712155
# 50%     7.534000        6.063821          8.129333   4.176087
# 75%     8.376500        7.566405          8.966000   5.410189
# max     9.968000        9.877942         10.000000   9.404642

# %% [markdown]
# #### 5.6. New correlation and plots

# %%
corr2 = scores2.corr()
corr2
# Out:
#                    Housing  Cost of Living  Business Freedom  Education
# Housing           1.000000        0.848162         -0.512734  -0.345077
# Cost of Living    0.848162        1.000000         -0.491136  -0.445386
# Business Freedom -0.512734       -0.491136          1.000000   0.781024
# Education        -0.345077       -0.445386          0.781024   1.000000

# %%
plt.figure(figsize = (9,9))

plt.subplot(2, 2, 1)
plt.hist(scores2['Housing'], color='#46327e')
plt.title(label='Housing');

plt.subplot(2, 2, 2)
plt.hist(scores2['Cost of Living'], color='#a0da39')
plt.title(label='Cost of Living');

plt.subplot(2, 2, 3)
plt.hist(scores2['Business Freedom'], color='#365c8d')
plt.title(label='Business Freedom');

plt.subplot(2, 2, 4)
plt.hist(scores2['Education'], color='#4ac16d')
plt.title(label='Education');

# %%
fig, (ax1, ax2, ax3)=plt.subplots(1,3, figsize=(15,4))
scores2.plot.scatter(x='Housing', y='Cost of Living', s=40, c='#46327e', ax=ax1);
scores2.plot.scatter(x='Housing', y='Business Freedom', s=40, c='#a0da39', ax=ax2);
scores2.plot.scatter(x='Housing', y='Education', s=40, c='#365c8d', ax=ax3);

fig, (ax1, ax2, ax3)=plt.subplots(1,3, figsize=(15,4))
scores2.plot.scatter(x='Cost of Living', y='Business Freedom', s=40, c='#4ac16d', ax=ax1);
scores2.plot.scatter(x='Cost of Living', y='Education', s=40, c='#46327e', ax=ax2);
scores2.plot.scatter(x='Business Freedom', y='Education', s=40, c='#46327e', ax=ax3);

# %%
g = sns.PairGrid(scores2)
g.map_upper(sns.scatterplot,color='#46327e')
g.map_lower(sns.scatterplot, color='#a0da39')
g.map_diag(sns.histplot);

# %%
scores.to_csv('scorestest.csv', index=False)

# %% [markdown]
# ### 6. Conclusion

# %% [markdown]
# If we take a look at the new generated data we can see that there are some similarities between our originial dataset _scores_ and the new _scores2_.
# Even though histograms don't completely match we can say the generated data followed the pattern of the initial distributions. The problem with the generated data is that the sample was too small for comparison so more datapoints should have been added.
# The correlation appeared to be similar to the correlation for variables in _scores_. New correlation between Housing and Cost of Living is **0.85** (in _scores_ **0.78**) and between Business Freedom and Education **0.80** (**0.67** in _scores_).

# %% [markdown]
# ### 7. References
#
# Aruchamy, V.(2021). Data Analytics with Pandas – How to Drop a List of Rows from a Pandas Dataframe, Retreived December 4 from https://www.freecodecamp.org/news/drop-list-of-rows-from-pandas-dataframe/
#     Fincher, J.(n.d.). Reading and Writing CSV Files in Python, Real Python, Retreived December 4, 2022 from https://realpython.com/python-csv/
#     GeeksforGeeks(2022). Adding new column to existing DataFrame in Pandas. Retreived December 4, 2022 from https://www.geeksforgeeks.org/adding-new-column-to-existing-dataframe-in-pandas/
#     Karaman, O.(n.d.). City Quality of Life Dataset., Version 1, Retreived December 4, 2022 from https://www.kaggle.com/datasets/orhankaramancode/city-quality-of-life-dataset
#     Kashe(2021). Data Handling Using Pandas. Removing Rows with zeros [Video]. YouTube. https://www.youtube.com/watch?v=i4cI4y9cLzg
#     Luvsandorj, Z.(2021). Prettifying pandas DataFrames. Retreived December 4, 2022 from https://towardsdatascience.com/prettifying-pandas-dataframes-75c1a1a6877d
#     McGinley, B.(2022). PfDA Project 1, Programming for Data Analysis, Atlantic Technological University
#     NNK(2022). Pandas Drop Columns from DataFrame., Retreived December 4 from https://sparkbyexamples.com/pandas/pandas-drop-columns-examples/
#     NumPy documentation(2022). Random Generator, Version 1.23, Retrieved December 4, 2022 from https://numpy.org/doc/stable/reference/random/generator.html
#     pandas documentation(2022). pandas.DataFrame.drop, Version 1.5.2, Retrieved December 4, 2022 from https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html
#     pandas documentation(2022). pandas.DataFrame.rename, Version 1.5.2, Retrieved December 4, 2022 from https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html
#     pandas documentation(2022). pandas.DataFrame.to_csv, Version 1.5.2, Retrieved December 4, 2022 from https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html
#     Session With Sumit(2020). How to plot multiple sub-plots using Matplotlib and Seaborn. Session With Sumit [Video]. YouTube. https://www.youtube.com/watch?v=4DnWYK88-E4
#     Teleport(n.d.). About us, Retreived December 4, 2022 from https://teleport.org/about-us/
#     Teleport(n.d.). Quality of Life in Dublin, Retreived December 4, 2022 from https://teleport.org/cities/dublin/
#     Özdemir, A.(n.d.). City Quality of Life (Data Visualization)., Version 3, Retrieved December 4 from  https://www.kaggle.com/code/ahmetozdemir1071/city-quality-of-life-data-visualization
#     Waskom, M.L.(2021). seaborn.stripplot, Version 0.12.1, Retrieved December 4, 2022 from https://seaborn.pydata.org/generated/seaborn.stripplot.html

# %%
sys.version
# Out:
# '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]'
