# %% [markdown]
# ### Programming for Data Analysis Project 1

# %% [markdown]
# ### 1. Introduction
#
# For this project we chose **Quality of Life** dataset by O.Karaman retreived from Kaggle platform.[[1]](https://www.kaggle.com/datasets/orhankaramancode/city-quality-of-life-dataset) Data were acquired from Teleport.org and contain scores on different variables about the life in the cities around the world allowing users to compare them in order to ease the decision of choosing a place to live. [[2]](https://teleport.org/about-us/)
#
# To simplify the analysis, we didn't use the entire dataset, instead we picked some of the variables we found the most interesting and explored the relationship between them. Initially, eight variables were chosen: Name of the City, Country, Continent and scores variables: Business Freedom, Safety, Education, Economy and Tolerance. The idea was to see how the Tolerance scores vary depending on the other scores variables but the correlation between them turned out to be low which made data generating more difficult. The choice of the variables was changed after we checked the correlation for the whole dataset. New variables that were analysed are: **City, Country, Continent, Housing, Cost of Living, Business Freedom and Education**.
#
# To describe what **variables** are representing we took a look behind data at Teleport.org:[[3]](https://teleport.org/cities/dublin/)
#
# **Housing** includes prices of the apartments and rent index,
# **Cost of Living** refers to groceries and transport expenses as well as the inflation score,
# **Business Freedom** implies freedom from corruption and labor restrictions,
# **Education** refers to PISA ranking, happiness of the students and university quality

# %% [markdown]
# ### 2. Exploring Data

# %% [markdown]
# Even though data were already pre-processed, since we didn't use the whole dataset, additional cleaning was done.
# First, we took a look at data as they were retrieved. They are uploaded in csv format as scoresData.csv.

# %% [markdown]
# #### 2.1. Importing libraries and reading data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns

# %%
scores = pd.read_csv('scoresData.csv')

# %% [markdown]
# To see the first couple of rows we used the head() function.
# We have 21 columns of which the first one shows indexes of rows, next three are Name (of the cities), Country and Continent for which the scores in the variables are shown.

# %%
scores.head()
# Out:
#    Unnamed: 0      UA_Name    UA_Country   UA_Continent  Housing  \
# 0           0       Aarhus       Denmark         Europe   6.1315
# 1           1     Adelaide     Australia        Oceania   6.3095
# 2           2  Albuquerque    New Mexico  North America   7.2620
# 3           3       Almaty    Kazakhstan           Asia   9.2820
# 4           4    Amsterdam   Netherlands         Europe   3.0530
#
#    Cost of Living  Startups  Venture Capital  Travel Connectivity  Commute  \
# 0           4.015    2.8270            2.512               3.5360  6.31175
# 1           4.692    3.1365            2.640               1.7765  5.33625
# 2           6.059    3.7720            1.493               1.4555  5.05575
# 3           9.333    2.4585            0.000               4.5920  5.87125
# 4           3.824    7.9715            6.107               8.3245  6.11850
#
#    ...  Safety  Healthcare  Education  Environmental Quality  Economy  \
# 0  ...  9.6165    8.704333     5.3665                7.63300   4.8865
# 1  ...  7.9260    7.936667     5.1420                8.33075   6.0695
# 2  ...  1.3435    6.430000     4.1520                7.31950   6.5145
# 3  ...  7.3090    4.545667     2.2830                3.85675   5.2690
# 4  ...  8.5035    7.907333     6.1800                7.59725   5.0530
#
#    Taxation  Internet Access  Leisure & Culture  Tolerance  Outdoors
# 0    5.0680            8.373             3.1870     9.7385    4.1300
# 1    4.5885            4.341             4.3285     7.8220    5.5310
# 2    4.3460            5.396             4.8900     7.0285    3.5155
# 3    8.5220            2.886             2.9370     6.5395    5.5000
# 4    4.9550            4.523             8.8740     8.3680    5.3070
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 2.2. Types of data

# %% [markdown]
# Types of data in dataframe are checked with the info() function. Scores for variables such as Housing, Cost of Living, Startups and the rest are float data type while categorial variables: Name (of the city), Country and Continent have object data types.
# According to the output none of the entries are null, there are no missing values, although, just by looking at data we can see zeroes are included. Since we didn't use the entire dataset, we dealt with zeroes later, after we picked the variables for analysis.

# %%
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             266 non-null    int64
#  1   UA_Name                266 non-null    object
#  2   UA_Country             266 non-null    object
#  3   UA_Continent           266 non-null    object
#  4   Housing                266 non-null    float64
#  5   Cost of Living         266 non-null    float64
#  6   Startups               266 non-null    float64
#  7   Venture Capital        266 non-null    float64
#  8   Travel Connectivity    266 non-null    float64
#  9   Commute                266 non-null    float64
#  10  Business Freedom       266 non-null    float64
#  11  Safety                 266 non-null    float64
#  12  Healthcare             266 non-null    float64
#  13  Education              266 non-null    float64
#  14  Environmental Quality  266 non-null    float64
#  15  Economy                266 non-null    float64
#  16  Taxation               266 non-null    float64
#  17  Internet Access        266 non-null    float64
#  18  Leisure & Culture      266 non-null    float64
#  19  Tolerance              266 non-null    float64
#  20  Outdoors               266 non-null    float64
# dtypes: float64(17), int64(1), object(3)
# memory usage: 43.8+ KB

# %% [markdown]
# ### 3. Data Cleaning

# %% [markdown]
# #### 3.1. Rename columns

# %% [markdown]
# To make dataset look neat we changed the names of the variables.

# %%
scores = scores.rename(columns={"UA_Name": "City", "UA_Country": "Country", "UA_Continent": "Continent"})
scores
# Out:
#      Unnamed: 0         City       Country      Continent  Housing  \
# 0             0       Aarhus       Denmark         Europe   6.1315
# 1             1     Adelaide     Australia        Oceania   6.3095
# 2             2  Albuquerque    New Mexico  North America   7.2620
# 3             3       Almaty    Kazakhstan           Asia   9.2820
# 4             4    Amsterdam   Netherlands         Europe   3.0530
# ..          ...          ...           ...            ...      ...
# 261         261     Winnipeg        Canada  North America   7.5525
# 262         262      Wroclaw        Poland         Europe   8.4520
# 263         263      Yerevan       Armenia           Asia   9.6945
# 264         264       Zagreb       Croatia         Europe   8.9100
# 265         265       Zurich   Switzerland         Europe   1.4730
#
#      Cost of Living  Startups  Venture Capital  Travel Connectivity  Commute  \
# 0             4.015    2.8270            2.512               3.5360  6.31175
# 1             4.692    3.1365            2.640               1.7765  5.33625
# 2             6.059    3.7720            1.493               1.4555  5.05575
# 3             9.333    2.4585            0.000               4.5920  5.87125
# 4             3.824    7.9715            6.107               8.3245  6.11850
# ..              ...       ...              ...                  ...      ...
# 261           5.882    3.7965            0.000               1.4755  5.10450
# 262           8.434    3.5860            2.386               2.2445  4.95475
# 263           9.431    3.9265            0.000               1.7870  5.64925
# 264           7.194    4.4530            1.775               2.0280  4.83000
# 265           1.000    6.2035            3.872               7.7335  5.83950
#
#      ...  Safety  Healthcare  Education  Environmental Quality  Economy  \
# 0    ...  9.6165    8.704333     5.3665                7.63300   4.8865
# 1    ...  7.9260    7.936667     5.1420                8.33075   6.0695
# 2    ...  1.3435    6.430000     4.1520                7.31950   6.5145
# 3    ...  7.3090    4.545667     2.2830                3.85675   5.2690
# 4    ...  8.5035    7.907333     6.1800                7.59725   5.0530
# ..   ...     ...         ...        ...                    ...      ...
# 261  ...  6.0155    7.755667     5.3440                5.67475   5.8405
# 262  ...  8.1655    6.781333     4.1615                4.96475   4.7615
# 263  ...  8.8730    5.102000     0.0000                4.43950   3.4580
# 264  ...  8.6575    7.266000     3.2110                7.33150   2.2365
# 265  ...  9.0665    7.670333     7.2875                8.64300   6.5520
#
#      Taxation  Internet Access  Leisure & Culture  Tolerance  Outdoors
# 0      5.0680           8.3730             3.1870     9.7385    4.1300
# 1      4.5885           4.3410             4.3285     7.8220    5.5310
# 2      4.3460           5.3960             4.8900     7.0285    3.5155
# 3      8.5220           2.8860             2.9370     6.5395    5.5000
# 4      4.9550           4.5230             8.8740     8.3680    5.3070
# ..        ...              ...                ...        ...       ...
# 261    7.2745           4.9025             4.6880     6.6590    4.2430
# 262    5.0970           5.7615             4.7495     3.9045    4.0850
# 263    8.0550           3.9000             4.7370     7.3465    7.7765
# 264    7.9935           5.0335             4.9945     7.9545    4.8090
# 265    6.4285           7.2675             4.9655     8.7845    5.4010
#
# [266 rows x 21 columns]

# %% [markdown]
# After exploring the ways of how to remove columns we don't want in a dataset, it was decided we are going to drop them by indexes.
# This was the initial choice of the variables: City, Country, Continent, Business Freedom, Safety, Education, Economy and Tolerance.

# %% [markdown]
# #### 3.2. Drop columns

# %%
# axis=1 because we are taking out columns, for rows would be axis=0
scores1 = scores.drop(scores.columns[[0, 4, 5, 6, 7, 8, 9, 12, 16, 14, 17, 18, 20]], axis=1)
scores1
# Out:
#             City       Country      Continent  Business Freedom  Safety  \
# 0         Aarhus       Denmark         Europe          9.940000  9.6165
# 1       Adelaide     Australia        Oceania          9.399667  7.9260
# 2    Albuquerque    New Mexico  North America          8.671000  1.3435
# 3         Almaty    Kazakhstan           Asia          5.568000  7.3090
# 4      Amsterdam   Netherlands         Europe          8.836667  8.5035
# ..           ...           ...            ...               ...     ...
# 261     Winnipeg        Canada  North America          8.966000  6.0155
# 262      Wroclaw        Poland         Europe          5.704333  8.1655
# 263      Yerevan       Armenia           Asia          6.501000  8.8730
# 264       Zagreb       Croatia         Europe          5.720333  8.6575
# 265       Zurich   Switzerland         Europe          8.888000  9.0665
#
#      Education  Economy  Tolerance
# 0       5.3665   4.8865     9.7385
# 1       5.1420   6.0695     7.8220
# 2       4.1520   6.5145     7.0285
# 3       2.2830   5.2690     6.5395
# 4       6.1800   5.0530     8.3680
# ..         ...      ...        ...
# 261     5.3440   5.8405     6.6590
# 262     4.1615   4.7615     3.9045
# 263     0.0000   3.4580     7.3465
# 264     3.2110   2.2365     7.9545
# 265     7.2875   6.5520     8.7845
#
# [266 rows x 8 columns]

# %% [markdown]
# #### 3.2. Correlation

# %% [markdown]
# The highest correlation in dataset scores1 was between Business Freedom and Education (**0.75**) and Business Freedom and Economy (**0.63**).
# Tolerance and Safety were not correlated well to any of the variables.

# %%
scores1.corr()
# Out:
#                   Business Freedom    Safety  Education   Economy  Tolerance
# Business Freedom          1.000000 -0.039642   0.757955  0.633438   0.362165
# Safety                   -0.039642  1.000000   0.063285 -0.241724   0.374310
# Education                 0.757955  0.063285   1.000000  0.513191   0.290475
# Economy                   0.633438 -0.241724   0.513191  1.000000   0.049305
# Tolerance                 0.362165  0.374310   0.290475  0.049305   1.000000

# %% [markdown]
# The correlation between all the variables was checked. To style the matrix we used this code [[4]](https://towardsdatascience.com/prettifying-pandas-dataframes-75c1a1a6877d)

# %%
type(scores.style)
# Out:
# pandas.io.formats.style.Styler

# %%
correlation_matrix = scores.corr()
(correlation_matrix.style
     .background_gradient(cmap='viridis', axis=None)
     .set_properties(**{'text-align': 'center', 'padding': '12px'})
     .set_caption('CORRELATION MATRIX'))
# Out:
# <style type="text/css">
# #T_1d916_row0_col0, #T_1d916_row1_col1, #T_1d916_row2_col2, #T_1d916_row3_col3, #T_1d916_row4_col4, #T_1d916_row5_col5, #T_1d916_row6_col6, #T_1d916_row7_col7, #T_1d916_row8_col8, #T_1d916_row9_col9, #T_1d916_row10_col10, #T_1d916_row11_col11, #T_1d916_row12_col12, #T_1d916_row13_col13, #T_1d916_row14_col14, #T_1d916_row15_col15, #T_1d916_row16_col16, #T_1d916_row17_col17 {
#   background-color: #fde725;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col1, #T_1d916_row1_col0, #T_1d916_row1_col13, #T_1d916_row1_col15, #T_1d916_row13_col1, #T_1d916_row15_col1 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col2, #T_1d916_row2_col0, #T_1d916_row3_col13, #T_1d916_row13_col3 {
#   background-color: #30698e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col3, #T_1d916_row3_col0 {
#   background-color: #2a768e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col4, #T_1d916_row4_col0, #T_1d916_row12_col16, #T_1d916_row16_col12 {
#   background-color: #2b748e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col5, #T_1d916_row5_col0, #T_1d916_row12_col17, #T_1d916_row17_col12 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col6, #T_1d916_row3_col6, #T_1d916_row6_col0, #T_1d916_row6_col3, #T_1d916_row14_col15, #T_1d916_row15_col14 {
#   background-color: #29798e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col7, #T_1d916_row7_col0, #T_1d916_row8_col10, #T_1d916_row10_col8 {
#   background-color: #2a778e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col8, #T_1d916_row6_col13, #T_1d916_row8_col0, #T_1d916_row12_col13, #T_1d916_row13_col6, #T_1d916_row13_col12 {
#   background-color: #297b8e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col9, #T_1d916_row0_col13, #T_1d916_row4_col11, #T_1d916_row9_col0, #T_1d916_row11_col4, #T_1d916_row11_col17, #T_1d916_row13_col0, #T_1d916_row17_col11 {
#   background-color: #287d8e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col10, #T_1d916_row7_col17, #T_1d916_row10_col0, #T_1d916_row17_col7 {
#   background-color: #297a8e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col11, #T_1d916_row0_col14, #T_1d916_row2_col3, #T_1d916_row3_col2, #T_1d916_row7_col13, #T_1d916_row11_col0, #T_1d916_row13_col7, #T_1d916_row14_col0 {
#   background-color: #2d718e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col12, #T_1d916_row11_col13, #T_1d916_row12_col0, #T_1d916_row13_col11, #T_1d916_row13_col17, #T_1d916_row14_col17, #T_1d916_row17_col13, #T_1d916_row17_col14 {
#   background-color: #31668e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col15, #T_1d916_row2_col15, #T_1d916_row15_col0, #T_1d916_row15_col2 {
#   background-color: #238a8d;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col16, #T_1d916_row2_col13, #T_1d916_row7_col15, #T_1d916_row13_col2, #T_1d916_row15_col7, #T_1d916_row16_col0, #T_1d916_row16_col17, #T_1d916_row17_col16 {
#   background-color: #2b758e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row0_col17, #T_1d916_row17_col0 {
#   background-color: #277f8e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row1_col2, #T_1d916_row2_col1, #T_1d916_row3_col4, #T_1d916_row4_col3 {
#   background-color: #a8db34;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row1_col3, #T_1d916_row3_col1 {
#   background-color: #472e7c;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row1_col4, #T_1d916_row4_col1 {
#   background-color: #481668;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row1_col5, #T_1d916_row1_col16, #T_1d916_row5_col1, #T_1d916_row16_col1 {
#   background-color: #404588;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row1_col6, #T_1d916_row6_col1 {
#   background-color: #23888e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row1_col7, #T_1d916_row7_col1 {
#   background-color: #481b6d;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row1_col8, #T_1d916_row3_col11, #T_1d916_row8_col1, #T_1d916_row11_col3 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row1_col9, #T_1d916_row1_col17, #T_1d916_row5_col13, #T_1d916_row9_col1, #T_1d916_row13_col5, #T_1d916_row17_col1 {
#   background-color: #3b518b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row1_col10, #T_1d916_row10_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row1_col11, #T_1d916_row11_col1 {
#   background-color: #481f70;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row1_col12, #T_1d916_row12_col1 {
#   background-color: #470e61;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row1_col14, #T_1d916_row14_col1 {
#   background-color: #453781;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row2_col4, #T_1d916_row2_col5, #T_1d916_row4_col2, #T_1d916_row5_col2 {
#   background-color: #39568c;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row2_col6, #T_1d916_row5_col8, #T_1d916_row6_col2, #T_1d916_row8_col5 {
#   background-color: #1f958b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row2_col7, #T_1d916_row7_col2 {
#   background-color: #481d6f;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row2_col8, #T_1d916_row8_col2, #T_1d916_row9_col13, #T_1d916_row10_col13, #T_1d916_row13_col9, #T_1d916_row13_col10, #T_1d916_row13_col15, #T_1d916_row15_col13 {
#   background-color: #34608d;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row2_col9, #T_1d916_row9_col2 {
#   background-color: #443983;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row2_col10, #T_1d916_row10_col2 {
#   background-color: #481c6e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row2_col11, #T_1d916_row11_col2 {
#   background-color: #481467;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row2_col12, #T_1d916_row12_col2 {
#   background-color: #46327e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row2_col14, #T_1d916_row14_col2 {
#   background-color: #423f85;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row2_col16, #T_1d916_row16_col2 {
#   background-color: #46307e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row2_col17, #T_1d916_row17_col2 {
#   background-color: #31688e;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row3_col5, #T_1d916_row5_col3 {
#   background-color: #1f988b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row3_col7, #T_1d916_row7_col3, #T_1d916_row14_col16, #T_1d916_row16_col14 {
#   background-color: #218f8d;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row3_col8, #T_1d916_row8_col3 {
#   background-color: #3e4989;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row3_col9, #T_1d916_row4_col16, #T_1d916_row9_col3, #T_1d916_row16_col4 {
#   background-color: #355e8d;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row3_col10, #T_1d916_row4_col12, #T_1d916_row8_col16, #T_1d916_row10_col3, #T_1d916_row12_col4, #T_1d916_row12_col14, #T_1d916_row14_col12, #T_1d916_row16_col8 {
#   background-color: #22a785;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row3_col12, #T_1d916_row12_col3 {
#   background-color: #1fa287;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row3_col14, #T_1d916_row14_col3 {
#   background-color: #228b8d;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_1d916_row3_

# %% [markdown]
# Based on correlation table we decided to keep **City, Country, Continent, Housing, Cost of Living, Business Freedom and Education.**

# %% [markdown]
# #### 3.3. Drop more columns

# %%
scores = scores.drop(scores.columns[[0, 6, 7, 8, 9, 11, 12, 14, 15, 16, 17, 18, 19, 20]], axis=1)
scores
# Out:
#             City       Country      Continent  Housing  Cost of Living  \
# 0         Aarhus       Denmark         Europe   6.1315           4.015
# 1       Adelaide     Australia        Oceania   6.3095           4.692
# 2    Albuquerque    New Mexico  North America   7.2620           6.059
# 3         Almaty    Kazakhstan           Asia   9.2820           9.333
# 4      Amsterdam   Netherlands         Europe   3.0530           3.824
# ..           ...           ...            ...      ...             ...
# 261     Winnipeg        Canada  North America   7.5525           5.882
# 262      Wroclaw        Poland         Europe   8.4520           8.434
# 263      Yerevan       Armenia           Asia   9.6945           9.431
# 264       Zagreb       Croatia         Europe   8.9100           7.194
# 265       Zurich   Switzerland         Europe   1.4730           1.000
#
#      Business Freedom  Education
# 0            9.940000     5.3665
# 1            9.399667     5.1420
# 2            8.671000     4.1520
# 3            5.568000     2.2830
# 4            8.836667     6.1800
# ..                ...        ...
# 261          8.966000     5.3440
# 262          5.704333     4.1615
# 263          6.501000     0.0000
# 264          5.720333     3.2110
# 265          8.888000     7.2875
#
# [266 rows x 7 columns]

# %% [markdown]
# #### 3.4. Zero values

# %% [markdown]
# Next, we checked for zeroes in columns containing scores. Index slicing was used to remove zero values. [[3]](https://www.youtube.com/watch?v=i4cI4y9cLzg)

# %%
scores.columns[3:]
# Out:
# Index(['Housing', 'Cost of Living', 'Business Freedom', 'Education'], dtype='object')

# %%
scores[(scores[scores.columns[3:]]==0).any(axis=1)]
# Out:
#                 City                  Country      Continent  Housing  \
# 6            Andorra                  Andorra         Europe   3.9690
# 9           Asuncion                 Paraguay  South America   9.2265
# 14              Baku               Azerbaijan           Asia   9.7450
# 15              Bali                Indonesia           Asia   5.0000
# 23       Belize City                   Belize  North America   4.6425
# 37           Bozeman                  Montana  North America   2.9490
# 52           Caracas                Venezuela  South America   4.9025
# 54        Casablanca                  Morocco         Africa   8.8220
# 73     Dar es Salaam                 Tanzania         Africa   7.6520
# 89      Fort Collins                 Colorado  North America   2.7445
# 91           Fukuoka                    Japan           Asia   4.0100
# 95         Gibraltar                Gibraltar         Europe   1.1120
# 100   Guatemala City                Guatemala  North America   8.8125
# 104           Havana                     Cuba  North America   9.0890
# 110        Hyderabad                    India           Asia  10.0000
# 119        Kathmandu                    Nepal           Asia  10.0000
# 121         Kingston                  Jamaica  North America   8.8955
# 125            Kyoto                    Japan           Asia   3.7650
# 126            Lagos                  Nigeria         Africa   7.7670
# 127           La Paz                  Bolivia  South America   4.7240
# 142             Lviv                  Ukraine         Europe   9.7780
# 148          Managua                Nicaragua  North America   4.7855
# 150           Manila              Philippines           Asia   8.5955
# 180             Oulu                  Finland         Europe   3.7445
# 182        Palo Alto               California  North America   0.5000
# 183           Panama                   Panama  North America   3.1530
# 187       Phnom Penh                 Cambodia           Asia   8.5520
# 191         Portland                    Maine  North America   0.0000
# 196       Providence             Rhode Island  North America   3.1530
# 198            Quito                  Ecuador  South America   9.0165
# 214         San Juan              Puerto Rico  North America   7.4275
# 215  San Luis Obispo               California  North America   1.7245
# 216     San Salvador              El Salvador  North America   8.8015
# 220         Sarajevo   Bosnia and Herzegovina         Europe   9.6925
# 238         Tashkent               Uzbekistan           Asia   5.0000
# 253         Valletta                    Malta         Europe   3.1530
# 263          Yerevan                  Armenia           Asia   9.6945
#
#      Cost of Living  Business Freedom  Education
# 6             0.000          0.000000     0.0000
# 9             9.295          3.684000     0.0000
# 14            9.806          5.671667     0.0000
# 15            0.000          3.912333     0.5275
# 23            0.000          3.411000     0.0000
# 37            0.000          8.671000     4.1280
# 52            9.820          1.000000     0.0000
# 54            9.088          5.614333     0.0000
# 73            8.026          3.288667     0.0000
# 89            0.000          8.671000     4.1735
# 91            0.000          8.389667     5.5275
# 95            0.000          0.000000     0.0000
# 100           8.175          4.617000     0.0000
# 104           7.608          1.643333     0.0000
# 110          10.000          3.618000     0.0000
# 119           9.445          4.740333     0.0000
# 121           5.937          6.567667     0.0000
# 125           0.000          8.389667     6.2410
# 126           9.098          3.255667     0.0000
# 127           0.000          3.482000     0.0000
# 142          10.000          4.525333     0.0000
# 148           0.000          4.600333     0.0000
# 150           8.752          4.592333     0.0000
# 180           0.000          9.450667     5.4545
# 182           0.000          8.671000     3.6245
# 183           0.000          6.208667     0.0000
# 187           8.001          1.000000     0.0000
# 191           0.000          8.671000     3.6245
# 196           0.000          8.671000     5.3015
# 198           7.822          3.021333     0.0000
# 214           5.980          3.173000     0.0000
# 215           0.000          8.671000     3.6245
# 216           7.743          4.661333     0.0000
# 220           8.659          2.580333     0.0000
# 238           0.000          5.175333     0.0000
# 253           0.000          5.377000     2.8195
# 263           9.431          6.501000     0.0000

# %% [markdown]
# After removing zeroes we got dataset of 229 rows through 7 columns

# %%
scores = scores[~(scores[scores.columns[3:]]==0).any(axis=1)]
scores
# Out:
#             City       Country      Continent  Housing  Cost of Living  \
# 0         Aarhus       Denmark         Europe   6.1315           4.015
# 1       Adelaide     Australia        Oceania   6.3095           4.692
# 2    Albuquerque    New Mexico  North America   7.2620           6.059
# 3         Almaty    Kazakhstan           Asia   9.2820           9.333
# 4      Amsterdam   Netherlands         Europe   3.0530           3.824
# ..           ...           ...            ...      ...             ...
# 260   Wellington   New Zealand        Oceania   5.1345           5.161
# 261     Winnipeg        Canada  North America   7.5525           5.882
# 262      Wroclaw        Poland         Europe   8.4520           8.434
# 264       Zagreb       Croatia         Europe   8.9100           7.194
# 265       Zurich   Switzerland         Europe   1.4730           1.000
#
#      Business Freedom  Education
# 0            9.940000     5.3665
# 1            9.399667     5.1420
# 2            8.671000     4.1520
# 3            5.568000     2.2830
# 4            8.836667     6.1800
# ..                ...        ...
# 260         10.000000     4.7560
# 261          8.966000     5.3440
# 262          5.704333     4.1615
# 264          5.720333     3.2110
# 265          8.888000     7.2875
#
# [229 rows x 7 columns]

# %% [markdown]
# #### 3.5. Round

# %% [markdown]
# To get all scores with the same number of decimals we used round function.

# %%
scores.round(decimals=3)
# Out:
#             City       Country      Continent  Housing  Cost of Living  \
# 0         Aarhus       Denmark         Europe    6.132           4.015
# 1       Adelaide     Australia        Oceania    6.310           4.692
# 2    Albuquerque    New Mexico  North America    7.262           6.059
# 3         Almaty    Kazakhstan           Asia    9.282           9.333
# 4      Amsterdam   Netherlands         Europe    3.053           3.824
# ..           ...           ...            ...      ...             ...
# 260   Wellington   New Zealand        Oceania    5.134           5.161
# 261     Winnipeg        Canada  North America    7.552           5.882
# 262      Wroclaw        Poland         Europe    8.452           8.434
# 264       Zagreb       Croatia         Europe    8.910           7.194
# 265       Zurich   Switzerland         Europe    1.473           1.000
#
#      Business Freedom  Education
# 0               9.940      5.366
# 1               9.400      5.142
# 2               8.671      4.152
# 3               5.568      2.283
# 4               8.837      6.180
# ..                ...        ...
# 260            10.000      4.756
# 261             8.966      5.344
# 262             5.704      4.162
# 264             5.720      3.211
# 265             8.888      7.288
#
# [229 rows x 7 columns]

# %% [markdown]
# ### 4. Statistics

# %% [markdown]
# #### 4.1. Descriptive statistics

# %%
scores.describe()
# Out:
#           Housing  Cost of Living  Business Freedom   Education
# count  229.000000      229.000000        229.000000  229.000000
# mean     6.531417        5.963904          7.710937    4.258179
# std      2.135435        1.878591          1.736523    1.929332
# min      1.000000        1.000000          2.781000    0.500000
# 25%      5.433500        4.927000          6.212667    3.624500
# 50%      6.727000        5.623000          8.671000    4.393500
# 75%      8.177000        7.237000          8.888000    5.345500
# max     10.000000       10.000000         10.000000    9.711000

# %% [markdown]
# #### 4.2. Group by continents

# %%
First, we grouped cities by continents, then we did strip plots of the variables.

# %%
scores['Continent'].value_counts()
# Out:
# Europe           105
# North America     73
# Asia              27
# South America     11
# Oceania            8
# Africa             5
# Name: Continent, dtype: int64

# %% [markdown]
# #### 4.3. Strip plots

# %% [markdown]
# Strip plot for each score variable grouped by continents. [[5]](https://seaborn.pydata.org/generated/seaborn.stripplot.html)

# %%
plt.figure(figsize = (25,25))

plt.subplot(5, 5, 1)
sns.stripplot(data=scores, x='Continent', y='Housing', jitter=False, s=20, marker="D", linewidth=1, alpha=.9, palette="viridis")
plt.xticks(rotation=60);

plt.subplot(5, 5, 2)
sns.stripplot(data=scores, x='Continent', y='Cost of Living', jitter=False, s=20, marker="D", linewidth=1, alpha=.9, palette="viridis")
plt.xticks(rotation=60);

# %%
plt.figure(figsize = (25,25))

plt.subplot(5, 5, 1)
sns.stripplot(data=scores, x='Continent', y='Business Freedom', jitter=False, s=20, marker="D", linewidth=1, alpha=.9, palette="viridis")
plt.xticks(rotation=60);

plt.subplot(5, 5, 2)
sns.stripplot(data=scores, x='Continent', y='Education', jitter=False, s=20, marker="D", linewidth=1, alpha=.9, palette="seismic_r")
plt.xticks(rotation=60);

# %%
print(sns.color_palette("seismic_r").as_hex())
# Out:
# ['#c80000', '#ff2525', '#ffb5b5', '#b5b5ff', '#2525ff', '#0000b1']

# %%
print(sns.color_palette("viridis").as_hex())
# Out:
# ['#46327e', '#365c8d', '#277f8e', '#1fa187', '#4ac16d', '#a0da39']

# %% [markdown]
# #### 4.4. Histograms

# %%
plt.figure(figsize = (9,9))

plt.subplot(2, 2, 1)
plt.hist(scores['Housing'], color='#46327e')
plt.title(label='Housing');

plt.subplot(2, 2, 2)
plt.hist(scores['Cost of Living'], color='#a0da39')
plt.title(label='Cost of Living');

plt.subplot(2, 2, 3)
plt.hist(scores['Business Freedom'], color='#365c8d')
plt.title(label='Business Freedom');

plt.subplot(2, 2, 4)
plt.hist(scores['Education'], color='#4ac16d')
plt.title(label='Education');

# %% [markdown]
# #### 4.5. Correlation

# %% [markdown]
# After checking the correlation between variables we created scatterplots and a pairplot. Positive correlation is found between Housing and Cost of Living (**0.78**) and Business Freedom and Education (**0.67**).
# Other correlations were negative, the highest between Cost of Living and Business Freedom (**-0.72**), Cost of Living and Education (**-0.69**) and Housing and Education (**-0.67**).

# %%
scores.corr()
# Out:
#                    Housing  Cost of Living  Business Freedom  Education
# Housing           1.000000        0.783637         -0.564009  -0.677656
# Cost of Living    0.783637        1.000000         -0.724444  -0.691075
# Business Freedom -0.564009       -0.724444          1.000000   0.677346
# Education        -0.677656       -0.691075          0.677346   1.000000

# %%
fig, (ax1, ax2, ax3)=plt.subplots(1,3, figsize=(15,4))
scores.plot.scatter(x='Housing', y='Cost of Living', s=40, c='#46327e', ax=ax1);
scores.plot.scatter(x='Housing', y='Business Freedom', s=40, c='#a0da39', ax=ax2);
scores.plot.scatter(x='Housing', y='Education', s=40, c='#365c8d', ax=ax3);

fig, (ax1, ax2, ax3)=plt.subplots(1,3, figsize=(15,4))
scores.plot.scatter(x='Cost of Living', y='Business Freedom', s=40, c='#4ac16d', ax=ax1);
scores.plot.scatter(x='Cost of Living', y='Education', s=40, c='#46327e', ax=ax2);
scores.plot.scatter(x='Business Freedom', y='Education', s=40, c='#46327e', ax=ax3);

# %%
cols = ['#4ac16d']
sns.set_palette(sns.color_palette(cols))
sns.pairplot(scores, palette=cols)
plt.grid(True)

# %%
g = sns.PairGrid(scores)
g.map_upper(sns.scatterplot,color='#46327e')
g.map_lower(sns.scatterplot, color='#a0da39')
g.map_diag(sns.histplot)

# %% [markdown]
# ### 5. Random number generator

# %% [markdown]
# We are going to take first 150 data for testing.

# %%
# These are data we are going to take out and keep in a different dataset
scorescontrol = scores.iloc[200:]
scorescontrol.to_csv('scorescontrol.csv')

# %%
controlread = pd.read_csv('scorescontrol.csv')
controlread
# Out:
#     Unnamed: 0            City                Country      Continent  Housing  \
# 0          234         Tallinn                Estonia         Europe   8.3765
# 1          235  Tampa Bay Area                Florida  North America   5.6960
# 2          236         Tampere                Finland         Europe   6.9360
# 3          237           Tartu                Estonia         Europe   8.9610
# 4          239         Tbilisi                Georgia         Europe   9.4905
# 5          240          Tehran                   Iran           Asia   8.3030
# 6          241        Tel Aviv                 Israel           Asia   4.9100
# 7          242       The Hague            Netherlands         Europe   6.0530
# 8          243    Thessaloniki                 Greece         Europe   9.3775
# 9          244           Tokyo                  Japan           Asia   5.6570
# 10         245         Toronto                 Canada  North America   4.6600
# 11         246        Toulouse                 France         Europe   7.5440
# 12         247           Tunis                Tunisia         Africa   9.9680
# 13         248           Turin                  Italy         Europe   8.0695
# 14         249           Turku                Finland         Europe   7.5340
# 15         250         Uppsala                 Sweden         Europe   7.1600
# 16         251         Utrecht            Netherlands         Europe   5.4665
# 17         252        Valencia                  Spain         Europe   8.1355
# 18         254       Vancouver                 Canada  North America   4.0805
# 19         255        Victoria                 Canada  North America   5.6960
# 20         256          Vienna                Austria         Europe   6.3140
# 21         257         Vilnius              Lithuania         Europe   8.6210
# 22         258          Warsaw                 Poland         Europe   7.8695
# 23         259      Washington   District of Columbia  North America   1.2105
# 24         260      Wellington            New Zealand        Oceania   5.1345
# 25         261        Winnipeg                 Canada  North America   7.5525
# 26         262         Wroclaw                 Poland         Europe   8.4520
# 27         264          Zagreb                Croatia         Europe   8.9100
# 28         265          Zurich            Switzerland         Europe   1.4730
#
#     Cost of Living  Business Freedom  Education
# 0            6.931          8.129333     5.3550
# 1            5.253          8.671000     4.2805
# 2            4.622          9.450667     5.3895
# 3            7.470          8.129333     5.4035
# 4            9.765          7.863333     0.8625
# 5            9.544          4.342667     0.5100
# 6            4.370          6.790000     3.7665
# 7            4.653          8.836667     4.3065
# 8            6.600          6.169000     3.1635
# 9            3.431          8.377667     6.9805
# 10           5.271          8.966000     7.6025
# 11           4.552          8.088333     4.4420
# 12           9.998          6.621667     0.5000
# 13           5.612          6.189667     4.1015
# 14           5.070          9.450667     5.3475
# 15           5.442          9.569000     5.2045
# 16           4.604          8.836667     5.5915
# 17           6.872          7.119667     4.2660
# 18           5.259          8.966000     6.8890
# 19           5.703          8.966000     5.3815
# 20           5.111          7.596000     4.8545
# 21           7.576          7.600333     3.7000
# 22           8.192          5.704333     4.6685
# 23           3.595          8.671000     5.9685
# 24           5.161         10.000000     4.7560
# 25           5.882          8.966000     5.3440
# 26           8.434          5.704333     4.1615
# 27           7.194          5.720333     3.2110
# 28           1.000          8.888000     7.2875

# %%
controlread = controlread.drop(controlread.columns[[0, 4, 6, 7, 8, 9]], axis=1)
controlread
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 controlread = controlread.drop(controlread.columns[[0, 4, 6, 7, 8, 9]], axis=1)
#       2 controlread
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5069, in Index.__getitem__(self, key)
#    5062 if com.is_bool_indexer(key):
#    5063     # if we have list[bools, length=1e5] then doing this check+convert
#    5064     #  takes 166 µs + 2.1 ms and cuts the ndarray.__getitem__
#    5065     #  time below from 3.8 ms to 496 µs
#    5066     # if we already have ndarray[bool], the overhead is 1.4 µs or .25%
#    5067     key = np.asarray(key, dtype=bool)
# -> 5069 result = getitem(key)
#    5070 # Because we ruled out integer above, we always get an arraylike here
#    5071 if result.ndim > 1:
#
# IndexError: index 8 is out of bounds for axis 0 with size 8

# %%
rng = np.random.default_rng()
def efg(bf):
    if bf <= 6.206917:
        return rng.random() * (3.624500-0.500000) + 0.500000
    if bf <= 8.671000:
        return rng.random() * (4.306500-3.624500) + 3.624500
    if bf <= 8.888000:
        return rng.random() * (5.302375-4.306500) + 4.306500
    else: 
        return rng.random() * (9.711000-5.302375) + 5.302375
    
efg(0.55)

# %%
controlread.insert(4, 'Education', True)
controlread['Education'] = controlread['Business Freedom'].apply(efg)
controlread

# %%
corr2 = controlread.corr()
corr2

# %%
scores = scores.iloc[:200]
scores

# %%
scores.to_csv('scorestest.csv', index=False)

# %%
correlation = scores.corr()
correlation

# %% [markdown]
# Random generator

# %%
#returns floating point number between 0 and 1
rng = np.random.default_rng()
rng.random()

# %%
scores

# %%
newVar = rng.normal(5.962835, 1.863146, size=200)
newVar

# %%
scores.insert(9, 'CostOfL2', newVar, True)
scores

# %%
plt.hist(scores['CostOfL2'])
plt.title(label='CostOfL2')
plt.savefig('CostOfL2_distribution')
plt.show()

# %%
newCorr = scores.corr()
newCorr

# %%
newVar = rng.normal(5.962835, 1.863146, size=200)
newVar

# %%
plt.hist(scores['newNewCostOfLiving'])
plt.title(label='newNewCostOfLiving')
#plt.savefig('newNewCostOfLiving_distribution')
plt.show()

# %% [markdown]
# References:
#     [1]: Karaman, O. (n.d.). City Quality of Life Dataset., Version 1, Retreived November 24, 2022 from https://www.kaggle.com/datasets/orhankaramancode/city-quality-of-life-dataset
#     [2]: Teleport, (n.d). About us, Retreived November 24, 2022 from https://teleport.org/about-us/

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html
# https://stackoverflow.com/questions/19482970/get-a-list-from-pandas-dataframe-column-headers
# https://www.geeksforgeeks.org/print-lists-in-python-4-different-ways/
# https://sparkbyexamples.com/pandas/pandas-drop-columns-examples/
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html
# https://www.youtube.com/watch?v=i4cI4y9cLzg
# https://www.freecodecamp.org/news/drop-list-of-rows-from-pandas-dataframe/
# https://www.youtube.com/watch?v=kprbThEGKf0
# https://www.geeksforgeeks.org/adding-new-column-to-existing-dataframe-in-pandas/
# https://numpy.org/doc/stable/reference/random/generator.html
# https://www.youtube.com/watch?v=4DnWYK88-E4
# https://www.kaggle.com/code/ahmetozdemir1071/city-quality-of-life-data-visualization
# https://seaborn.pydata.org/generated/seaborn.stripplot.html
# https://towardsdatascience.com/prettifying-pandas-dataframes-75c1a1a6877d
# https://teleport.org/cities/dublin/
# https://www.analyticsvidhya.com/blog/2020/09/colormaps-matplotlib/
# https://towardsdatascience.com/how-to-use-your-own-color-palettes-with-seaborn-a45bf5175146
