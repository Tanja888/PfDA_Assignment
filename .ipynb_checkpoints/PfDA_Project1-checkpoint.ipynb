# %% [markdown]
# ### Programming for Data Analysis Project 1

# %% [markdown]
# ### Introduction
#
# For this project we chose Quality of Life dataset by O.Karaman retreived from Kaggle platform.[[1]](https://www.kaggle.com/datasets/orhankaramancode/city-quality-of-life-dataset) Data were acquired from Teleport.org and contain scores on different variables about the life in the cities around the world allowing the users to compare them in order to ease the decision of choosing a place to live. [[2]](https://teleport.org/about-us/)
#
# To simplify the analysis, we will not be using the entire dataset, instead we are going to pick some of the variables we find the most interesting and explore the relationship between them. (add more here)

# %% [markdown]
# ### Exploring Data

# %% [markdown]
# Even though data were already pre-processed, since we are not going to use the whole dataset, we will do additional cleaning but first, we are going to take a look at data as we retrieved them. They are uploaded in csv format as scoresData.csv.

# %%
# Importing libraries we are going to use:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns

# %%
scores = pd.read_csv('scoresData.csv')

# %% [markdown]
# To see the first couple of rows we are using the head() function.
# We have 21 columns of which the first one shows indexes of rows, next three are Name (of the cities), Country and Continent for which the scores in the variables are shown.

# %%
scores.head()
# Out:
#    Unnamed: 0      UA_Name    UA_Country   UA_Continent  Housing  \
# 0           0       Aarhus       Denmark         Europe   6.1315
# 1           1     Adelaide     Australia        Oceania   6.3095
# 2           2  Albuquerque    New Mexico  North America   7.2620
# 3           3       Almaty    Kazakhstan           Asia   9.2820
# 4           4    Amsterdam   Netherlands         Europe   3.0530
#
#    Cost of Living  Startups  Venture Capital  Travel Connectivity  Commute  \
# 0           4.015    2.8270            2.512               3.5360  6.31175
# 1           4.692    3.1365            2.640               1.7765  5.33625
# 2           6.059    3.7720            1.493               1.4555  5.05575
# 3           9.333    2.4585            0.000               4.5920  5.87125
# 4           3.824    7.9715            6.107               8.3245  6.11850
#
#    ...  Safety  Healthcare  Education  Environmental Quality  Economy  \
# 0  ...  9.6165    8.704333     5.3665                7.63300   4.8865
# 1  ...  7.9260    7.936667     5.1420                8.33075   6.0695
# 2  ...  1.3435    6.430000     4.1520                7.31950   6.5145
# 3  ...  7.3090    4.545667     2.2830                3.85675   5.2690
# 4  ...  8.5035    7.907333     6.1800                7.59725   5.0530
#
#    Taxation  Internet Access  Leisure & Culture  Tolerance  Outdoors
# 0    5.0680            8.373             3.1870     9.7385    4.1300
# 1    4.5885            4.341             4.3285     7.8220    5.5310
# 2    4.3460            5.396             4.8900     7.0285    3.5155
# 3    8.5220            2.886             2.9370     6.5395    5.5000
# 4    4.9550            4.523             8.8740     8.3680    5.3070
#
# [5 rows x 21 columns]

# %% [markdown]
# Types of data in the dataframe are checked with the info() function. Scores for variables such as Housing, Cost of Living, Startups and the rest are float data type while categorial variables: Name (of the city), Country and Continent have object data types.
# According to the output none of the entries are null, there are no missing values, although, just by looking at data we can see zeroes are included. Since we are not going to use the entire dataset, we will deal with zeroes later, after we pick the variables for analysis.

# %%
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             266 non-null    int64
#  1   UA_Name                266 non-null    object
#  2   UA_Country             266 non-null    object
#  3   UA_Continent           266 non-null    object
#  4   Housing                266 non-null    float64
#  5   Cost of Living         266 non-null    float64
#  6   Startups               266 non-null    float64
#  7   Venture Capital        266 non-null    float64
#  8   Travel Connectivity    266 non-null    float64
#  9   Commute                266 non-null    float64
#  10  Business Freedom       266 non-null    float64
#  11  Safety                 266 non-null    float64
#  12  Healthcare             266 non-null    float64
#  13  Education              266 non-null    float64
#  14  Environmental Quality  266 non-null    float64
#  15  Economy                266 non-null    float64
#  16  Taxation               266 non-null    float64
#  17  Internet Access        266 non-null    float64
#  18  Leisure & Culture      266 non-null    float64
#  19  Tolerance              266 non-null    float64
#  20  Outdoors               266 non-null    float64
# dtypes: float64(17), int64(1), object(3)
# memory usage: 43.8+ KB

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# After exploring the ways of how to remove columns we don't want in a dataset, it was decided we are going to drop them by indexes.

# %%
# axis=1 because we are taking out columns, for rows would be axis=0
scores = scores.drop(scores.columns[[0, 4, 6, 7, 8, 9, 12, 16, 14, 17, 18, 20]], axis=1)
scores
# Out:
#          UA_Name    UA_Country   UA_Continent  Cost of Living  \
# 0         Aarhus       Denmark         Europe           4.015
# 1       Adelaide     Australia        Oceania           4.692
# 2    Albuquerque    New Mexico  North America           6.059
# 3         Almaty    Kazakhstan           Asia           9.333
# 4      Amsterdam   Netherlands         Europe           3.824
# ..           ...           ...            ...             ...
# 261     Winnipeg        Canada  North America           5.882
# 262      Wroclaw        Poland         Europe           8.434
# 263      Yerevan       Armenia           Asia           9.431
# 264       Zagreb       Croatia         Europe           7.194
# 265       Zurich   Switzerland         Europe           1.000
#
#      Business Freedom  Safety  Education  Economy  Tolerance
# 0            9.940000  9.6165     5.3665   4.8865     9.7385
# 1            9.399667  7.9260     5.1420   6.0695     7.8220
# 2            8.671000  1.3435     4.1520   6.5145     7.0285
# 3            5.568000  7.3090     2.2830   5.2690     6.5395
# 4            8.836667  8.5035     6.1800   5.0530     8.3680
# ..                ...     ...        ...      ...        ...
# 261          8.966000  6.0155     5.3440   5.8405     6.6590
# 262          5.704333  8.1655     4.1615   4.7615     3.9045
# 263          6.501000  8.8730     0.0000   3.4580     7.3465
# 264          5.720333  8.6575     3.2110   2.2365     7.9545
# 265          8.888000  9.0665     7.2875   6.5520     8.7845
#
# [266 rows x 9 columns]

# %% [markdown]
# To make a dataframe look nicer we changed the names of the variables

# %%
scores = scores.rename(columns={"UA_Name": "City", "UA_Country": "Country", "UA_Continent": "Continent"})
scores
# Out:
#             City       Country      Continent  Cost of Living  \
# 0         Aarhus       Denmark         Europe           4.015
# 1       Adelaide     Australia        Oceania           4.692
# 2    Albuquerque    New Mexico  North America           6.059
# 3         Almaty    Kazakhstan           Asia           9.333
# 4      Amsterdam   Netherlands         Europe           3.824
# ..           ...           ...            ...             ...
# 261     Winnipeg        Canada  North America           5.882
# 262      Wroclaw        Poland         Europe           8.434
# 263      Yerevan       Armenia           Asia           9.431
# 264       Zagreb       Croatia         Europe           7.194
# 265       Zurich   Switzerland         Europe           1.000
#
#      Business Freedom  Safety  Education  Economy  Tolerance
# 0            9.940000  9.6165     5.3665   4.8865     9.7385
# 1            9.399667  7.9260     5.1420   6.0695     7.8220
# 2            8.671000  1.3435     4.1520   6.5145     7.0285
# 3            5.568000  7.3090     2.2830   5.2690     6.5395
# 4            8.836667  8.5035     6.1800   5.0530     8.3680
# ..                ...     ...        ...      ...        ...
# 261          8.966000  6.0155     5.3440   5.8405     6.6590
# 262          5.704333  8.1655     4.1615   4.7615     3.9045
# 263          6.501000  8.8730     0.0000   3.4580     7.3465
# 264          5.720333  8.6575     3.2110   2.2365     7.9545
# 265          8.888000  9.0665     7.2875   6.5520     8.7845
#
# [266 rows x 9 columns]

# %% [markdown]
# Next, we checked for zeroes in columns containing scores. Index slicing was used to remove zeroe values. [[3]](https://www.youtube.com/watch?v=i4cI4y9cLzg)

# %%
scores.columns[3:]
# Out:
# Index(['Cost of Living', 'Business Freedom', 'Safety', 'Education', 'Economy',
#        'Tolerance'],
#       dtype='object')

# %%
scores[(scores[scores.columns[3:]]==0).any(axis=1)]
# Out:
#                 City                  Country      Continent  Cost of Living  \
# 6            Andorra                  Andorra         Europe           0.000
# 9           Asuncion                 Paraguay  South America           9.295
# 14              Baku               Azerbaijan           Asia           9.806
# 15              Bali                Indonesia           Asia           0.000
# 23       Belize City                   Belize  North America           0.000
# 37           Bozeman                  Montana  North America           0.000
# 52           Caracas                Venezuela  South America           9.820
# 54        Casablanca                  Morocco         Africa           9.088
# 73     Dar es Salaam                 Tanzania         Africa           8.026
# 89      Fort Collins                 Colorado  North America           0.000
# 91           Fukuoka                    Japan           Asia           0.000
# 95         Gibraltar                Gibraltar         Europe           0.000
# 100   Guatemala City                Guatemala  North America           8.175
# 104           Havana                     Cuba  North America           7.608
# 110        Hyderabad                    India           Asia          10.000
# 119        Kathmandu                    Nepal           Asia           9.445
# 121         Kingston                  Jamaica  North America           5.937
# 125            Kyoto                    Japan           Asia           0.000
# 126            Lagos                  Nigeria         Africa           9.098
# 127           La Paz                  Bolivia  South America           0.000
# 142             Lviv                  Ukraine         Europe          10.000
# 148          Managua                Nicaragua  North America           0.000
# 150           Manila              Philippines           Asia           8.752
# 180             Oulu                  Finland         Europe           0.000
# 182        Palo Alto               California  North America           0.000
# 183           Panama                   Panama  North America           0.000
# 187       Phnom Penh                 Cambodia           Asia           8.001
# 191         Portland                    Maine  North America           0.000
# 196       Providence             Rhode Island  North America           0.000
# 198            Quito                  Ecuador  South America           7.822
# 214         San Juan              Puerto Rico  North America           5.980
# 215  San Luis Obispo               California  North America           0.000
# 216     San Salvador              El Salvador  North America           7.743
# 220         Sarajevo   Bosnia and Herzegovina         Europe           8.659
# 238         Tashkent               Uzbekistan           Asia           0.000
# 253         Valletta                    Malta         Europe           0.000
# 263          Yerevan                  Armenia           Asia           9.431
#
#      Business Freedom   Safety  Education  Economy  Tolerance
# 6            0.000000   9.5535     0.0000   0.0000     8.7035
# 9            3.684000   6.9345     0.0000   4.1090     7.0515
# 14           5.671667   8.7720     0.0000   3.8765     6.5845
# 15           3.912333   8.7475     0.5275   4.6575     4.5590
# 23           3.411000   6.0520     0.0000   3.4960     6.8650
# 37           8.671000   6.9145     4.1280   6.5145     7.2935
# 52           1.000000   5.2210     0.0000   1.9780     4.5505
# 54           5.614333   6.7755     0.0000   3.1735     2.9450
# 73           3.288667   6.1005     0.0000   5.5000     2.7665
# 89           8.671000   6.9355     4.1735   6.5145     9.4800
# 91           8.389667   9.9450     5.5275   3.7235     7.2590
# 95           0.000000   9.3375     0.0000   0.0000     4.4265
# 100          4.617000   6.1390     0.0000   3.8050     7.1570
# 104          1.643333   8.6335     0.0000   2.5495     8.7595
# 110          3.618000   8.1265     0.0000   5.5565     4.1325
# 119          4.740333   8.5055     0.0000   4.4960     9.1290
# 121          6.567667   5.5275     0.0000   1.8295     2.8435
# 125          8.389667  10.0000     6.2410   3.7235     7.6630
# 126          3.255667   5.9995     0.0000   5.0610     1.4060
# 127          3.482000   6.7505     0.0000   4.5360     6.2930
# 142          4.525333   7.8220     0.0000   1.2755     6.7160
# 148          4.600333   7.7745     0.0000   3.9395     9.2390
# 150          4.592333   6.4345     0.0000   5.0065     5.5030
# 180          9.450667   8.4585     5.4545   3.9210     8.3290
# 182          8.671000   7.6370     3.6245   6.5145     8.4540
# 183          6.208667   6.9760     0.0000   6.0405     6.7855
# 187          1.000000   6.6840     0.0000   5.3800     6.0305
# 191          8.671000   6.3585     3.6245   6.5145     8.2710
# 196          8.671000   6.8460     5.3015   6.5145     7.4900
# 198          3.021333   6.9690     0.0000   3.8855     8.8265
# 214          3.173000   5.1210     0.0000   0.0000     3.6600
# 215          8.671000   8.0580     3.6245   6.5145     9.6660
# 216          4.661333   5.4025     0.0000   2.6590     6.1275
# 220          2.580333   7.1330     0.0000   2.0880     7.7365
# 238          5.175333   8.9045     0.0000   5.5375     6.1705
# 253          5.377000   8.5180     2.8195   5.5395     7.5630
# 263          6.501000   8.8730     0.0000   3.4580     7.3465

# %% [markdown]
# After removing zero values, our new dataset contains 240 rows over 8 columns.

# %%
scores = scores[~(scores[scores.columns[3:]]==0).any(axis=1)]
scores
# Out:
#             City       Country      Continent  Cost of Living  \
# 0         Aarhus       Denmark         Europe           4.015
# 1       Adelaide     Australia        Oceania           4.692
# 2    Albuquerque    New Mexico  North America           6.059
# 3         Almaty    Kazakhstan           Asia           9.333
# 4      Amsterdam   Netherlands         Europe           3.824
# ..           ...           ...            ...             ...
# 260   Wellington   New Zealand        Oceania           5.161
# 261     Winnipeg        Canada  North America           5.882
# 262      Wroclaw        Poland         Europe           8.434
# 264       Zagreb       Croatia         Europe           7.194
# 265       Zurich   Switzerland         Europe           1.000
#
#      Business Freedom  Safety  Education  Economy  Tolerance
# 0            9.940000  9.6165     5.3665   4.8865     9.7385
# 1            9.399667  7.9260     5.1420   6.0695     7.8220
# 2            8.671000  1.3435     4.1520   6.5145     7.0285
# 3            5.568000  7.3090     2.2830   5.2690     6.5395
# 4            8.836667  8.5035     6.1800   5.0530     8.3680
# ..                ...     ...        ...      ...        ...
# 260         10.000000  8.2230     4.7560   5.5055     8.1160
# 261          8.966000  6.0155     5.3440   5.8405     6.6590
# 262          5.704333  8.1655     4.1615   4.7615     3.9045
# 264          5.720333  8.6575     3.2110   2.2365     7.9545
# 265          8.888000  9.0665     7.2875   6.5520     8.7845
#
# [229 rows x 9 columns]

# %% [markdown]
# We are going to take first 150 data to run the testing.

# %%
# These are data we are going to take out and keep in a different dataset
scorescontrol = scores.iloc[200:]
scorescontrol.to_csv('scorescontrol.csv')

# %%
controlread = pd.read_csv('scorescontrol.csv')
controlread
# Out:
#     Unnamed: 0            City                Country      Continent  \
# 0          234         Tallinn                Estonia         Europe
# 1          235  Tampa Bay Area                Florida  North America
# 2          236         Tampere                Finland         Europe
# 3          237           Tartu                Estonia         Europe
# 4          239         Tbilisi                Georgia         Europe
# 5          240          Tehran                   Iran           Asia
# 6          241        Tel Aviv                 Israel           Asia
# 7          242       The Hague            Netherlands         Europe
# 8          243    Thessaloniki                 Greece         Europe
# 9          244           Tokyo                  Japan           Asia
# 10         245         Toronto                 Canada  North America
# 11         246        Toulouse                 France         Europe
# 12         247           Tunis                Tunisia         Africa
# 13         248           Turin                  Italy         Europe
# 14         249           Turku                Finland         Europe
# 15         250         Uppsala                 Sweden         Europe
# 16         251         Utrecht            Netherlands         Europe
# 17         252        Valencia                  Spain         Europe
# 18         254       Vancouver                 Canada  North America
# 19         255        Victoria                 Canada  North America
# 20         256          Vienna                Austria         Europe
# 21         257         Vilnius              Lithuania         Europe
# 22         258          Warsaw                 Poland         Europe
# 23         259      Washington   District of Columbia  North America
# 24         260      Wellington            New Zealand        Oceania
# 25         261        Winnipeg                 Canada  North America
# 26         262         Wroclaw                 Poland         Europe
# 27         264          Zagreb                Croatia         Europe
# 28         265          Zurich            Switzerland         Europe
#
#     Cost of Living  Business Freedom   Safety  Education  Economy  Tolerance
# 0            6.931          8.129333   9.4255     5.3550   4.1850     7.8385
# 1            5.253          8.671000   4.7065     4.2805   6.5145     5.3600
# 2            4.622          9.450667   8.6890     5.3895   3.9210     8.2905
# 3            7.470          8.129333   9.3765     5.4035   4.1850     7.4830
# 4            9.765          7.863333   9.5060     0.8625   4.2525     8.1975
# 5            9.544          4.342667   6.7930     0.5100   3.9435     4.2225
# 6            4.370          6.790000   8.0065     3.7665   5.0265     5.5160
# 7            4.653          8.836667   8.7890     4.3065   5.0530     8.5530
# 8            6.600          6.169000   7.9920     3.1635   3.3200     7.5235
# 9            3.431          8.377667  10.0000     6.9805   3.7235     7.1945
# 10           5.271          8.966000   7.6935     7.6025   5.8405     7.9280
# 11           4.552          8.088333   6.9670     4.4420   4.2045     7.6335
# 12           9.998          6.621667   8.2915     0.5000   3.0920     4.7270
# 13           5.612          6.189667   6.2520     4.1015   3.3625     5.7770
# 14           5.070          9.450667   9.1755     5.3475   3.9210     7.7515
# 15           5.442          9.569000   7.8500     5.2045   5.6945     6.9505
# 16           4.604          8.836667   8.6310     5.5915   5.0530     8.5655
# 17           6.872          7.119667   7.7865     4.2660   4.2960     7.9350
# 18           5.259          8.966000   7.5695     6.8890   5.8405     8.2950
# 19           5.703          8.966000   7.8080     5.3815   5.8405     8.7825
# 20           5.111          7.596000   8.5965     4.8545   4.6630     8.9640
# 21           7.576          7.600333   8.8570     3.7000   4.6910     7.3930
# 22           8.192          5.704333   8.6995     4.6685   4.7615     4.6360
# 23           3.595          8.671000   2.1915     5.9685   6.5145     6.5495
# 24           5.161         10.000000   8.2230     4.7560   5.5055     8.1160
# 25           5.882          8.966000   6.0155     5.3440   5.8405     6.6590
# 26           8.434          5.704333   8.1655     4.1615   4.7615     3.9045
# 27           7.194          5.720333   8.6575     3.2110   2.2365     7.9545
# 28           1.000          8.888000   9.0665     7.2875   6.5520     8.7845

# %%
controlread = controlread.drop(controlread.columns[[0, 4, 6, 7, 8, 9]], axis=1)
controlread
# Out:
#               City                Country      Continent  Business Freedom
# 0          Tallinn                Estonia         Europe          8.129333
# 1   Tampa Bay Area                Florida  North America          8.671000
# 2          Tampere                Finland         Europe          9.450667
# 3            Tartu                Estonia         Europe          8.129333
# 4          Tbilisi                Georgia         Europe          7.863333
# 5           Tehran                   Iran           Asia          4.342667
# 6         Tel Aviv                 Israel           Asia          6.790000
# 7        The Hague            Netherlands         Europe          8.836667
# 8     Thessaloniki                 Greece         Europe          6.169000
# 9            Tokyo                  Japan           Asia          8.377667
# 10         Toronto                 Canada  North America          8.966000
# 11        Toulouse                 France         Europe          8.088333
# 12           Tunis                Tunisia         Africa          6.621667
# 13           Turin                  Italy         Europe          6.189667
# 14           Turku                Finland         Europe          9.450667
# 15         Uppsala                 Sweden         Europe          9.569000
# 16         Utrecht            Netherlands         Europe          8.836667
# 17        Valencia                  Spain         Europe          7.119667
# 18       Vancouver                 Canada  North America          8.966000
# 19        Victoria                 Canada  North America          8.966000
# 20          Vienna                Austria         Europe          7.596000
# 21         Vilnius              Lithuania         Europe          7.600333
# 22          Warsaw                 Poland         Europe          5.704333
# 23      Washington   District of Columbia  North America          8.671000
# 24      Wellington            New Zealand        Oceania         10.000000
# 25        Winnipeg                 Canada  North America          8.966000
# 26         Wroclaw                 Poland         Europe          5.704333
# 27          Zagreb                Croatia         Europe          5.720333
# 28          Zurich            Switzerland         Europe          8.888000

# %%
rng = np.random.default_rng()
def efg(bf):
    if bf <= 6.206917:
        return rng.random() * (3.624500-0.500000) + 0.500000
    if bf <= 8.671000:
        return rng.random() * (4.306500-3.624500) + 3.624500
    if bf <= 8.888000:
        return rng.random() * (5.302375-4.306500) + 4.306500
    else: 
        return rng.random() * (9.711000-5.302375) + 5.302375
    
efg(0.55)
# Out:
# 0.7903674990455168

# %%
controlread.insert(4, 'Education', True)
controlread['Education'] = controlread['Business Freedom'].apply(efg)
controlread
# Out:
#               City                Country      Continent  Business Freedom  \
# 0          Tallinn                Estonia         Europe          8.129333
# 1   Tampa Bay Area                Florida  North America          8.671000
# 2          Tampere                Finland         Europe          9.450667
# 3            Tartu                Estonia         Europe          8.129333
# 4          Tbilisi                Georgia         Europe          7.863333
# 5           Tehran                   Iran           Asia          4.342667
# 6         Tel Aviv                 Israel           Asia          6.790000
# 7        The Hague            Netherlands         Europe          8.836667
# 8     Thessaloniki                 Greece         Europe          6.169000
# 9            Tokyo                  Japan           Asia          8.377667
# 10         Toronto                 Canada  North America          8.966000
# 11        Toulouse                 France         Europe          8.088333
# 12           Tunis                Tunisia         Africa          6.621667
# 13           Turin                  Italy         Europe          6.189667
# 14           Turku                Finland         Europe          9.450667
# 15         Uppsala                 Sweden         Europe          9.569000
# 16         Utrecht            Netherlands         Europe          8.836667
# 17        Valencia                  Spain         Europe          7.119667
# 18       Vancouver                 Canada  North America          8.966000
# 19        Victoria                 Canada  North America          8.966000
# 20          Vienna                Austria         Europe          7.596000
# 21         Vilnius              Lithuania         Europe          7.600333
# 22          Warsaw                 Poland         Europe          5.704333
# 23      Washington   District of Columbia  North America          8.671000
# 24      Wellington            New Zealand        Oceania         10.000000
# 25        Winnipeg                 Canada  North America          8.966000
# 26         Wroclaw                 Poland         Europe          5.704333
# 27          Zagreb                Croatia         Europe          5.720333
# 28          Zurich            Switzerland         Europe          8.888000
#
#     Education
# 0    4.133065
# 1    3.949281
# 2    8.176757
# 3    3.804796
# 4    3.926452
# 5    1.122749
# 6    3.879514
# 7    5.129113
# 8    0.645883
# 9    3.735788
# 10   5.700778
# 11   3.955552
# 12   3.670295
# 13   3.298631
# 14   8.791285
# 15   6.648930
# 16   4.673521
# 17   3.848534
# 18   8.351719
# 19   5.957716
# 20   3.762956
# 21   4.263505
# 22   2.973843
# 23   4.294604
# 24   8.677649
# 25   8.052289
# 26   1.362288
# 27   2.841675
# 28   4.338539

# %%
corr2 = controlread.corr()
corr2
# Out:
#                   Business Freedom  Education
# Business Freedom          1.000000   0.826872
# Education                 0.826872   1.000000

# %%
scores = scores.iloc[:200]
scores
# Out:
#             City       Country      Continent  Cost of Living  \
# 0         Aarhus       Denmark         Europe           4.015
# 1       Adelaide     Australia        Oceania           4.692
# 2    Albuquerque    New Mexico  North America           6.059
# 3         Almaty    Kazakhstan           Asia           9.333
# 4      Amsterdam   Netherlands         Europe           3.824
# ..           ...           ...            ...             ...
# 229    St. Louis      Missouri  North America           5.504
# 230    Stockholm        Sweden         Europe           4.360
# 231    Stuttgart       Germany         Europe           5.673
# 232       Sydney     Australia        Oceania           4.128
# 233       Taipei        Taiwan           Asia           5.644
#
#      Business Freedom  Safety  Education  Economy  Tolerance
# 0            9.940000  9.6165     5.3665   4.8865     9.7385
# 1            9.399667  7.9260     5.1420   6.0695     7.8220
# 2            8.671000  1.3435     4.1520   6.5145     7.0285
# 3            5.568000  7.3090     2.2830   5.2690     6.5395
# 4            8.836667  8.5035     6.1800   5.0530     8.3680
# ..                ...     ...        ...      ...        ...
# 229          8.671000  3.8805     5.2715   6.5145     4.3760
# 230          9.569000  6.8865     6.6675   5.6945     5.7195
# 231          9.072333  8.2695     5.0505   5.3735     7.5335
# 232          9.399667  7.5710     6.7255   6.0695     7.0325
# 233          8.341667  9.5420     5.5895   6.6355     8.0435
#
# [200 rows x 9 columns]

# %% [markdown]
# To get all scores with the same number of decimals we used round function.

# %%
scores.round(decimals=4)
# Out:
#             City       Country      Continent  Cost of Living  \
# 0         Aarhus       Denmark         Europe           4.015
# 1       Adelaide     Australia        Oceania           4.692
# 2    Albuquerque    New Mexico  North America           6.059
# 3         Almaty    Kazakhstan           Asia           9.333
# 4      Amsterdam   Netherlands         Europe           3.824
# ..           ...           ...            ...             ...
# 229    St. Louis      Missouri  North America           5.504
# 230    Stockholm        Sweden         Europe           4.360
# 231    Stuttgart       Germany         Europe           5.673
# 232       Sydney     Australia        Oceania           4.128
# 233       Taipei        Taiwan           Asia           5.644
#
#      Business Freedom  Safety  Education  Economy  Tolerance
# 0              9.9400  9.6165     5.3665   4.8865     9.7385
# 1              9.3997  7.9260     5.1420   6.0695     7.8220
# 2              8.6710  1.3435     4.1520   6.5145     7.0285
# 3              5.5680  7.3090     2.2830   5.2690     6.5395
# 4              8.8367  8.5035     6.1800   5.0530     8.3680
# ..                ...     ...        ...      ...        ...
# 229            8.6710  3.8805     5.2715   6.5145     4.3760
# 230            9.5690  6.8865     6.6675   5.6945     5.7195
# 231            9.0723  8.2695     5.0505   5.3735     7.5335
# 232            9.3997  7.5710     6.7255   6.0695     7.0325
# 233            8.3417  9.5420     5.5895   6.6355     8.0435
#
# [200 rows x 9 columns]

# %%
scores.to_csv('scorestest.csv', index=False)

# %% [markdown]
# ### Statistics

# %% [markdown]
# Group cities by continents

# %%
scores['Continent'].value_counts()
# Out:
# Europe           87
# North America    67
# Asia             24
# South America    11
# Oceania           7
# Africa            4
# Name: Continent, dtype: int64

# %% [markdown]
# Descriptive statistics

# %%
scores.describe()
# Out:
#        Cost of Living  Business Freedom      Safety   Education     Economy  \
# count      200.000000        200.000000  200.000000  200.000000  200.000000
# mean         5.962835          7.687105    6.748665    4.209138    5.293908
# std          1.863146          1.778135    1.776871    1.950519    1.408664
# min          1.000000          2.781000    1.343500    0.500000    1.275500
# 25%          4.932250          6.206917    5.651875    3.624500    4.273125
# 50%          5.641000          8.671000    7.089000    4.306500    5.438000
# 75%          7.260000          8.888000    7.929500    5.302375    6.514500
# max         10.000000         10.000000   10.000000    9.711000    9.390000
#
#         Tolerance
# count  200.000000
# mean     6.778008
# std      1.682179
# min      1.528000
# 25%      5.782625
# 50%      7.091000
# 75%      8.000125
# max      9.738500

# %%
#do histograms nicer

# %%
plt.figure(figsize = (9,9))

plt.subplot(2, 2, 1)
plt.hist(scores['Cost of Living'])
plt.title(label='Cost of Living Distribution');

plt.subplot(2, 2, 2)
plt.hist(scores['Business Freedom'], color='pink')
plt.title(label='Business Freedom');

plt.subplot(2, 2, 3)
plt.hist(scores['Safety'], color='#e6e1e0')
plt.title(label='Safety');

# %%
plt.hist(scores['Cost of Living'], color='pink')
plt.title(label='Cost of Living Distribution')
plt.savefig('CoL_distribution')
plt.show()

# %%
plt.hist(scores['Business Freedom'])
plt.title(label='Business Freedom Distribution')
plt.savefig('BF_distribution')
plt.show()

# %%
plt.hist(scores['Safety'], color='green')
plt.title(label='Safety')
plt.savefig('Safety_distribution')
plt.show()

# %%
plt.hist(scores['Education'])
plt.title(label='Education')
plt.savefig('Education_distribution')
plt.show()

# %%
plt.hist(scores['Economy'])
plt.title(label='Economy')
plt.savefig('Economy_distribution')
plt.show()

# %%
plt.hist(scores['Tolerance'])
plt.title(label='Tolerance')
plt.savefig('Tolerance_distribution')
plt.show()

# %%
correlation = scores.corr()
correlation
# Out:
#                   Cost of Living  Business Freedom    Safety  Education  \
# Cost of Living          1.000000         -0.742662 -0.011178  -0.683704
# Business Freedom       -0.742662          1.000000 -0.021388   0.681713
# Safety                 -0.011178         -0.021388  1.000000   0.108789
# Education              -0.683704          0.681713  0.108789   1.000000
# Economy                -0.509653          0.618213 -0.216606   0.475641
# Tolerance              -0.354130          0.371194  0.383798   0.258807
#
#                    Economy  Tolerance
# Cost of Living   -0.509653  -0.354130
# Business Freedom  0.618213   0.371194
# Safety           -0.216606   0.383798
# Education         0.475641   0.258807
# Economy           1.000000  -0.014757
# Tolerance        -0.014757   1.000000

# %% [markdown]
# Random generator

# %%
#returns floating point number between 0 and 1
rng = np.random.default_rng()
rng.random()
# Out:
# 0.4215458821254974

# %%
scores
# Out:
#             City       Country      Continent  Cost of Living  \
# 0         Aarhus       Denmark         Europe           4.015
# 1       Adelaide     Australia        Oceania           4.692
# 2    Albuquerque    New Mexico  North America           6.059
# 3         Almaty    Kazakhstan           Asia           9.333
# 4      Amsterdam   Netherlands         Europe           3.824
# ..           ...           ...            ...             ...
# 229    St. Louis      Missouri  North America           5.504
# 230    Stockholm        Sweden         Europe           4.360
# 231    Stuttgart       Germany         Europe           5.673
# 232       Sydney     Australia        Oceania           4.128
# 233       Taipei        Taiwan           Asia           5.644
#
#      Business Freedom  Safety  Education  Economy  Tolerance
# 0            9.940000  9.6165     5.3665   4.8865     9.7385
# 1            9.399667  7.9260     5.1420   6.0695     7.8220
# 2            8.671000  1.3435     4.1520   6.5145     7.0285
# 3            5.568000  7.3090     2.2830   5.2690     6.5395
# 4            8.836667  8.5035     6.1800   5.0530     8.3680
# ..                ...     ...        ...      ...        ...
# 229          8.671000  3.8805     5.2715   6.5145     4.3760
# 230          9.569000  6.8865     6.6675   5.6945     5.7195
# 231          9.072333  8.2695     5.0505   5.3735     7.5335
# 232          9.399667  7.5710     6.7255   6.0695     7.0325
# 233          8.341667  9.5420     5.5895   6.6355     8.0435
#
# [200 rows x 9 columns]

# %%
newVar = rng.normal(5.962835, 1.863146, size=200)
newVar
# Out:
# array([ 8.98570977,  5.27066191,  4.69922045,  8.43851165,  7.53651428,
#         4.24797464,  1.64566928,  4.63877996,  8.23376347,  2.79868519,
#         4.07312351,  5.36966049,  7.20428432,  7.39584297,  5.33940143,
#         8.42485405,  7.0956306 ,  8.45080095,  4.57938795,  3.27029005,
#         5.34030735,  6.74134172,  4.71655236,  2.40174592,  3.38245501,
#         6.1914972 ,  6.64454118,  3.43383294,  2.81590571,  4.84989877,
#         5.79623874,  6.88022336,  4.338258  ,  6.40052456,  4.79855695,
#         3.56275373,  9.068647  ,  7.67091826,  6.44537476,  4.4487089 ,
#         8.61799789,  7.5614215 ,  7.53366467,  8.89013011,  5.0844225 ,
#         4.95166731,  5.64196072,  8.99087651,  2.92060227,  3.79264207,
#         8.28423761,  5.16707792,  5.37329825,  6.34266356,  8.37104181,
#         5.49991188,  2.61080684,  6.76295228,  8.77648232,  8.1008967 ,
#         3.96601225,  4.53745124,  5.21026102,  2.4943586 ,  4.59475582,
#         7.43958232,  4.68306762,  5.30211279,  3.82256563,  6.47958829,
#         8.51789871,  5.64186849,  6.20006337,  4.97568283,  4.83497949,
#         9.07569497,  6.49787812,  5.6376806 ,  2.75993033,  5.07992968,
#         5.75970769,  6.08281542,  5.3724702 ,  8.51401251,  7.4225969 ,
#         8.13515861,  8.85138985,  7.90239494,  6.24581627,  2.63035005,
#         9.57354538,  5.35175658,  9.5346559 ,  6.67921293,  5.63477408,
#         5.38070098,  8.36951589,  6.68527543,  4.76145838,  2.16559967,
#         4.96450583,  5.64127178,  7.1202605 ,  7.69645188,  6.06351117,
#         5.70597646,  5.19967938,  7.70390351,  7.70782779,  5.81398612,
#         9.33414794,  6.88431306,  5.8259481 ,  6.4231591 ,  6.43108894,
#         7.77818667,  4.47096653,  4.85363814,  5.75581764,  5.9182718 ,
#         8.75551996,  4.25809385,  7.72359686,  5.30366463,  3.71977578,
#         5.6670875 ,  5.53284343,  6.48084709,  6.35857851,  9.00301469,
#         2.2593232 ,  7.9814786 ,  7.15595631,  6.59513201,  6.05757259,
#         5.72812333,  2.35953272,  6.1125011 ,  4.75484127,  4.36771249,
#         3.38035618,  4.86719202,  6.7712613 ,  6.33838138,  6.54844085,
#         8.53641762,  3.3911692 , 10.6392775 ,  8.24811651,  2.16326915,
#         4.85078986,  2.90870801,  6.53755346, 10.47226013,  8.15893839,
#         6.32228682,  4.86115627,  4.162128  ,  4.25966377,  4.23360048,
#         5.13473331,  5.29606869,  5.98297232,  8.40145823,  6.70796123,
#         6.48900543,  7.38725466,  7.83730217,  8.6735388 ,  6.42913938,
#         5.67780716,  8.39370068,  5.44745095,  4.77567012,  2.53493948,
#         6.24559318,  5.60190206,  6.13304649,  5.05468988,  6.3466513 ,
#         2.74262635,  6.87017699,  4.69762049,  4.76990975,  3.04297451,
#         7.45871494,  6.67482106,  3.84601085,  4.03305483,  5.69411384,
#         8.79565296,  5.36446249,  6.46789108,  4.22436045,  5.16082195,
#         8.63422568,  6.13094267,  7.70287958,  3.39920542,  4.74118236])

# %%
scores.insert(9, 'CostOfL2', newVar, True)
scores
# Out:
#             City       Country      Continent  Cost of Living  \
# 0         Aarhus       Denmark         Europe           4.015
# 1       Adelaide     Australia        Oceania           4.692
# 2    Albuquerque    New Mexico  North America           6.059
# 3         Almaty    Kazakhstan           Asia           9.333
# 4      Amsterdam   Netherlands         Europe           3.824
# ..           ...           ...            ...             ...
# 229    St. Louis      Missouri  North America           5.504
# 230    Stockholm        Sweden         Europe           4.360
# 231    Stuttgart       Germany         Europe           5.673
# 232       Sydney     Australia        Oceania           4.128
# 233       Taipei        Taiwan           Asia           5.644
#
#      Business Freedom  Safety  Education  Economy  Tolerance  CostOfL2
# 0            9.940000  9.6165     5.3665   4.8865     9.7385  8.985710
# 1            9.399667  7.9260     5.1420   6.0695     7.8220  5.270662
# 2            8.671000  1.3435     4.1520   6.5145     7.0285  4.699220
# 3            5.568000  7.3090     2.2830   5.2690     6.5395  8.438512
# 4            8.836667  8.5035     6.1800   5.0530     8.3680  7.536514
# ..                ...     ...        ...      ...        ...       ...
# 229          8.671000  3.8805     5.2715   6.5145     4.3760  8.634226
# 230          9.569000  6.8865     6.6675   5.6945     5.7195  6.130943
# 231          9.072333  8.2695     5.0505   5.3735     7.5335  7.702880
# 232          9.399667  7.5710     6.7255   6.0695     7.0325  3.399205
# 233          8.341667  9.5420     5.5895   6.6355     8.0435  4.741182
#
# [200 rows x 10 columns]

# %%
plt.hist(scores['CostOfL2'])
plt.title(label='CostOfL2')
plt.savefig('CostOfL2_distribution')
plt.show()

# %%
newCorr = scores.corr()
newCorr
# Out:
#                   Cost of Living  Business Freedom    Safety  Education  \
# Cost of Living          1.000000         -0.742662 -0.011178  -0.683704
# Business Freedom       -0.742662          1.000000 -0.021388   0.681713
# Safety                 -0.011178         -0.021388  1.000000   0.108789
# Education              -0.683704          0.681713  0.108789   1.000000
# Economy                -0.509653          0.618213 -0.216606   0.475641
# Tolerance              -0.354130          0.371194  0.383798   0.258807
# CostOfL2                0.009194         -0.013381  0.040555   0.025143
#
#                    Economy  Tolerance  CostOfL2
# Cost of Living   -0.509653  -0.354130  0.009194
# Business Freedom  0.618213   0.371194 -0.013381
# Safety           -0.216606   0.383798  0.040555
# Education         0.475641   0.258807  0.025143
# Economy           1.000000  -0.014757 -0.003267
# Tolerance        -0.014757   1.000000  0.097049
# CostOfL2         -0.003267   0.097049  1.000000

# %%
scores.describe()
# Out:
#        Cost of Living  Business Freedom      Safety   Education     Economy  \
# count      200.000000        200.000000  200.000000  200.000000  200.000000
# mean         5.962835          7.687105    6.748665    4.209138    5.293908
# std          1.863146          1.778135    1.776871    1.950519    1.408664
# min          1.000000          2.781000    1.343500    0.500000    1.275500
# 25%          4.932250          6.206917    5.651875    3.624500    4.273125
# 50%          5.641000          8.671000    7.089000    4.306500    5.438000
# 75%          7.260000          8.888000    7.929500    5.302375    6.514500
# max         10.000000         10.000000   10.000000    9.711000    9.390000
#
#         Tolerance    CostOfL2
# count  200.000000  200.000000
# mean     6.778008    5.939140
# std      1.682179    1.871580
# min      1.528000    1.645669
# 25%      5.782625    4.751427
# 50%      7.091000    5.777973
# 75%      8.000125    7.402531
# max      9.738500   10.639278

# %%
newVar = rng.normal(5.962835, 1.863146, size=200)
newVar
# Out:
# array([ 3.52616053,  9.10912999,  4.2834854 ,  3.5989286 ,  6.23973831,
#         5.22175189,  6.36908644,  7.71930911,  7.35790837,  6.69937769,
#         6.44473401,  5.03989503,  7.23111809,  6.8148255 ,  7.10319641,
#         4.14471388,  4.99263448,  8.10630793,  4.48503815,  4.40123096,
#         2.91006314,  6.93333007,  7.74822686,  4.05329202,  5.31334033,
#         4.9840465 ,  2.9039341 ,  4.09568487,  5.34847116,  7.02189154,
#         8.42965702,  5.44452374,  5.68690042,  6.33196657,  7.76800977,
#         4.30964472,  7.0057765 ,  6.38261503,  5.90219288,  8.12652465,
#         5.9476781 ,  8.607434  ,  4.62817049,  9.25518018,  6.490375  ,
#         6.4050927 ,  5.321626  ,  7.46906509,  9.89700132,  6.71171082,
#         4.1920044 ,  6.55361395,  5.11020073,  6.13072429,  6.0120889 ,
#         5.55862182,  7.59960168,  7.08432106,  6.60746121,  4.97575096,
#         9.95640313,  7.08408732,  6.02069811,  4.57802503,  5.1474664 ,
#         7.62138834,  4.63671935,  5.38190445,  5.57551945,  4.37377877,
#         7.07319211,  6.04743209,  7.15178057,  3.23439586,  5.46088261,
#         5.35116437, 11.10694319,  9.41402845,  7.68283883,  4.33979071,
#         7.3150153 ,  6.30574622,  4.64469761,  8.0756905 ,  4.74168457,
#         4.80759194,  5.56479094,  8.01165741,  4.16823953,  4.63186403,
#         5.09199098,  6.02356214,  6.4430089 ,  3.64143575,  6.51061275,
#         8.80210445,  6.03880818,  5.1666855 ,  9.17893928,  7.2955271 ,
#         3.58929273,  1.46088371,  9.37014801,  6.78041508,  1.33940492,
#         5.67155618,  4.42686761,  4.72812638,  7.96332204,  8.63708614,
#         8.21165589,  7.04895054,  6.29528174,  6.73722601,  5.45368049,
#         4.89810122,  6.43423235,  4.62336095,  3.86913395,  4.8252338 ,
#         7.48576326,  5.47123763,  6.12713119,  5.72396686,  8.84546649,
#         4.12860491,  5.68424164,  1.19599785,  1.91870191,  7.77237198,
#         5.66641281,  9.61740916,  7.06187531,  8.97280357,  5.79579678,
#         7.33626407,  3.7065811 ,  3.61957368,  7.14263663,  6.09735582,
#         4.4397728 ,  9.36161601,  7.66791787,  8.14979112,  7.95875559,
#         1.36340553,  4.7813152 ,  7.86326401,  7.54106058,  4.48906601,
#         6.43455198,  5.21882985,  3.95875854,  6.39115614,  4.43251647,
#         5.92608591,  6.8481731 ,  7.19886626,  0.41345152,  6.56516391,
#         6.68556109,  4.94676895,  4.71337706,  5.13770112,  4.32655823,
#         7.66231172,  6.31351816,  5.78908193,  3.13662713,  4.8935664 ,
#         7.50655739,  7.68288599,  7.07254394,  3.8942871 ,  8.23886469,
#         7.74882485,  4.21621592,  6.62949469,  7.47473235, 10.35302854,
#         3.23392832,  5.34396019,  2.77469485,  8.57140767,  6.86440725,
#         5.96963583,  5.79185759,  6.72765773,  9.5638672 ,  2.99219822,
#         6.92975687,  9.30841583,  3.81777949,  6.9925997 ,  6.5995094 ,
#         6.03341672,  4.79668539,  4.66456812,  5.79728533,  4.97243575])

# %%
plt.hist(scores['newNewCostOfLiving'])
plt.title(label='newNewCostOfLiving')
plt.savefig('newNewCostOfLiving_distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'newNewCostOfLiving'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 plt.hist(scores['newNewCostOfLiving'])
#       2 plt.title(label='newNewCostOfLiving')
#       3 plt.savefig('newNewCostOfLiving_distribution')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'newNewCostOfLiving'

# %% [markdown]
# References:
#     [1]: Karaman, O. (n.d.). City Quality of Life Dataset., Version 1, Retreived November 24, 2022 from https://www.kaggle.com/datasets/orhankaramancode/city-quality-of-life-dataset
#     [2]: Teleport, (n.d). About us, Retreived November 24, 2022 from https://teleport.org/about-us/

# %%
https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html    
https://stackoverflow.com/questions/19482970/get-a-list-from-pandas-dataframe-column-headers  
https://www.geeksforgeeks.org/print-lists-in-python-4-different-ways/  
https://sparkbyexamples.com/pandas/pandas-drop-columns-examples/  
https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html  
https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html  
https://www.youtube.com/watch?v=i4cI4y9cLzg  
https://www.freecodecamp.org/news/drop-list-of-rows-from-pandas-dataframe/    
https://www.youtube.com/watch?v=kprbThEGKf0  
https://www.geeksforgeeks.org/adding-new-column-to-existing-dataframe-in-pandas/  
https://numpy.org/doc/stable/reference/random/generator.html
https://www.youtube.com/watch?v=4DnWYK88-E4
